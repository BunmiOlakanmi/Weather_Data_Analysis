# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ## Observations and Insights
#
# ### Analysis
#
# * On the overall, most cities analysed are from the northern hemisphere. That is, 374 of the 559 random cities selected when the code was last executed, belong to the northern hemisphere.
# *  With respect to the scatter plots, there is a negative non-linear correlation observed in the relationship between city's latitude and temperature, while there is a positive correlation between the city's latitude and humidity. This is understandable because most cities selected are from the northern hemisphere, and the temperature is expected to drop as we move towards the pole, while the humidity is expected to increase. However, there is no correlation observed in the relationships between city's latitude and cloudiness, and between city's latitude and the wind speed.
# *  With respect to linear regression, cities in both northern and southern hemispheres have strong correlation between max temperature and latitude, although the cities in the northern hemisphere have a negative correlation. This is understandable because generally around the world, it gets warmer towards the equator and cooler towards the poles.

# %%
# Import all dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json 
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Generate Cities List

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))

# Print Cities List
print(cities)
# Out:
# 604
# ['hilo', 'nayoro', 'kodiak', 'pueblo', 'salalah', 'georgetown', 'ushuaia', 'carnarvon', 'belushya guba', 'sundumbili', 'soyo', 'sorong', 'mataura', 'nikolskoye', 'esperance', 'chokurdakh', 'krasnogvardeyets', 'axim', 'lompoc', 'saint george', 'paamiut', 'rikitea', 'solnechnyy', 'pevek', 'san patricio', 'atuona', 'vardo', 'ojinaga', 'berlevag', 'samusu', 'ancud', 'norman wells', 'palmer', 'barentsburg', 'jamestown', 'saint-pierre', 'punta arenas', 'nanortalik', 'nanao', 'bluff', 'upernavik', 'atbasar', 'saskylakh', 'husavik', 'albany', 'tasiilaq', 'port alfred', 'cape town', 'plettenberg bay', 'komsomolskiy', 'grand river south east', 'tsihombe', 'airai', 'avera', 'aguie', 'taolanaro', 'novobessergenevka', 'tuatapere', 'umm lajj', 'garissa', 'cabo san lucas', 'hasaki', 'east london', 'tongren', 'hobart', 'exu', 'ende', 'pisco', 'avarua', 'kapaa', 'vaini', 'pangnirtung', 'kaitangata', 'aksarka', 'barrow', 'puerto ayora', 'yellowknife', 'arrecife', 'zhicheng', 'nanchong', 'kamenka', 'arraial do cabo', 'jaguarari', 'rocha', 'butaritari', 'vao', 'pakxe', 'vuktyl', 'puerto del rosario', 'iqaluit', 'tuktoyaktuk', 'tarpon springs', 'camacha', 'lavrentiya', 'biltine', 'hermanus', 'bredasdorp', 'zastron', 'qaanaaq', 'malumfashi', 'ribeira grande', 'taseyevo', 'kenai', 'mahebourg', 'cherskiy', 'busselton', 'grants', 'katsuura', 'amderma', 'tiksi', 'champerico', 'kavieng', 'matara', 'beira', 'brae', 'khandyga', 'maamba', 'praia da vitoria', 'margate', 'high level', 'isangel', 'creetown', 'qarqin', 'rochegda', 'pucallpa', 'te anau', 'muzhi', 'illoqqortoormiut', 'marovoay', 'hithadhoo', 'torbay', 'bonavista', 'cayenne', 'kruisfontein', 'bandarbeyla', 'hirado', 'tasbuget', 'victoria', 'visnes', 'scottsbluff', 'kamaishi', 'teya', 'lolua', 'faanui', 'pecos', 'luderitz', 'matagami', 'ishigaki', 'hualmay', 'mount isa', 'castro', 'uni', 'lincoln', 'morgan city', 'tunduru', 'provideniya', 'sitka', 'mengcheng', 'nhulunbuy', 'pimentel', 'manokwari', 'caravelas', 'rincon', 'quixeramobim', 'dikson', 'smiltene', 'kidero', 'kloulklubed', 'sataua', 'vila franca do campo', 'los llanos de aridane', 'caucaia', 'turukhansk', 'casablanca', 'longyearbyen', 'sangueya', 'tateyama', 'tromso', 'fortuna', 'payette', 'attawapiskat', 'mar del plata', 'parana', 'umba', 'san quintin', 'flinders', 'cockburn town', 'lebu', 'sayyan', 'mezen', 'luyang', 'bargal', 'nuuk', 'chingirlau', 'huarmey', 'pemba', 'sur', 'prainha', 'new norfolk', 'port elizabeth', 'sao jose da coroa grande', 'belyy yar', 'lao cai', 'guerrero negro', 'bambous virieux', 'artyom', 'lagoa', 'marfino', 'riyadh', 'bengkulu', 'hit', 'clyde river', 'kalmunai', 'angoram', 'tretten', 'aksu', 'campoverde', 'port hedland', 'zhoucheng', 'port hardy', 'gat', 'balykshi', 'aksehir', 'ayorou', 'namibe', 'wilmington', 'penzance', 'viana', 'khonuu', 'aklavik', 'anadyr', 'korla', 'luanda', 'richards bay', 'port blair', 'saint anthony', 'sao filipe', 'mujiayingzi', 'sedan', 'ponta do sol', 'maracacume', 'nelson bay', 'ostrovnoy', 'hami', 'paracatu', 'port shepstone', 'hobyo', 'hatillo', 'mys shmidta', 'auki', 'matay', 'aras', 'coihaique', 'yumen', 'tarudant', 'bubaque', 'nome', 'campina verde', 'villa carlos paz', 'krasnorechenskiy', 'traralgon', 'dunedin', 'kaeo', 'beringovskiy', 'bojnurd', 'sambava', 'kortkeros', 'ust-kamchatsk', 'linkou', 'severo-yeniseyskiy', 'asau', 'zhigansk', 'vestmannaeyjar', 'itapirapua', 'grindavik', 'el tocuyo', 'fomboni', 'zhanaozen', 'punta alta', 'garoua boulai', 'pishin', 'yar-sale', 'bathsheba', 'gouyave', 'quelimane', 'fairbanks', 'saint-philippe', 'kota kinabalu', 'shache', 'riaba', 'maragogi', 'obo', 'alyangula', 'itaituba', 'necochea', 'darhan', 'westport', 'yatou', 'olafsvik', 'praia', 'severo-kurilsk', 'great yarmouth', 'piraju', 'fairlie', 'deputatskiy', 'acajutla', 'chiradzulu', 'atar', 'saldanha', 'nara', 'mogadishu', 'garowe', 'mayo', 'akyab', 'sorland', 'khatanga', 'havre-saint-pierre', 'myaundzha', 'voh', 'nyrob', 'port-gentil', 'yichun', 'adrar', 'codajas', 'ngukurr', 'hamza ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Components of API 
city_data = []
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Initialize a counter to store the city number
counter = 1

# Perform a weather check 
# on each of the cities using a series of successive API calls
# Then, extract the weather components (latitude, temperature, wind speed..)
# needed for our analyses and charts
for city in cities:
    try:
        query_url = f"{url}&appid={weather_api_key}&units={units}&q={city}"
        weather_response = requests.get(query_url).json()
        city_humidity = weather_response["main"]["humidity"]
        city_temp = weather_response["main"]["temp"]
        city_Maxtemp = weather_response["main"]["temp_max"]
        city_lat = weather_response["coord"]["lat"] 
        city_wind = weather_response["wind"]["speed"]
        city_cloud = weather_response["clouds"]["all"]
        city_country = weather_response["sys"]["country"]
        city_datetime = weather_response["dt"]
        city_lon = weather_response["coord"]["lon"]
        # Print a log of each city with the city number and city name
        print(f"processing record number {counter} | {city}")
        counter += 1
        city_data.append ({"City":city,
                           "Country": city_country,
                           "DateTime":city_datetime,
                           "Humidity": city_humidity,
                           "Temperature": city_temp,
                           "Max. Temp.":  city_Maxtemp,
                           "Latitude": city_lat,
                           "WindSpeed": city_wind,
                           "Cloudiness": city_cloud,
                           "Longitude": city_lon
                     })        
    except:
        # Print city does not exist, if the city details are missing
        print("City does not exist")
        pass
# Out:
# processing record number 1 | hilo
# processing record number 2 | nayoro
# processing record number 3 | kodiak
# processing record number 4 | pueblo
# processing record number 5 | salalah
# processing record number 6 | georgetown
# processing record number 7 | ushuaia
# processing record number 8 | carnarvon
# City does not exist
# processing record number 9 | sundumbili
# processing record number 10 | soyo
# processing record number 11 | sorong
# processing record number 12 | mataura
# processing record number 13 | nikolskoye
# processing record number 14 | esperance
# processing record number 15 | chokurdakh
# processing record number 16 | krasnogvardeyets
# processing record number 17 | axim
# processing record number 18 | lompoc
# processing record number 19 | saint george
# processing record number 20 | paamiut
# processing record number 21 | rikitea
# processing record number 22 | solnechnyy
# processing record number 23 | pevek
# processing record number 24 | san patricio
# processing record number 25 | atuona
# processing record number 26 | vardo
# processing record number 27 | ojinaga
# processing record number 28 | berlevag
# City does not exist
# processing record number 29 | ancud
# processing record number 30 | norman wells
# processing record number 31 | palmer
# City does not exist
# processing record number 32 | jamestown
# processing record number 33 | saint-pierre
# processing record number 34 | punta arenas
# processing record number 35 | nanortalik
# processing record number 36 | nanao
# processing record number 37 | bluff
# processing record number 38 | upernavik
# processing record number 39 | atbasar
# processing record number 40 | saskylakh
# processing record number 41 | husavik
# processing record number 42 | albany
# processing record number 43 | tasiilaq
# processing record number 44 | port alfred
# processing record number 45 | cape town
# processing record number 46 | plettenberg bay
# processing record number 47 | komsomolskiy
# City does not exist
# City does not exist
# processing record number 48 | airai
# processing record number 49 | avera
# processing record number 50 | aguie
# City does not exist
# processing record number 51 | novobessergenevka
# processing record number 52 | tuatapere
# processing record number 53 | umm lajj
# processing record number 54 | garissa
# processing record number 55 | cabo san lucas
# processing record number 56 | hasaki
# processing record number 57 | east london
# processing record number 58 | tongren
# processing record number 59 | hobart
# processing record number 60 | exu
# processing record number 61 | ende
# processing record number 62 | pisco
# processing record number 63 | avarua
# processing record number 64 | kapaa
# processing record number 65 | vaini
# processing record number 66 | pangnirtung
# processing record number 67 | kaitangata
# processing record number 68 | aksarka
# processing record number 69 | barrow
# processing record number 70 | puerto ayora
# processing record number 71 | yellowknife
# processing record number 72 | arrecife
# processing record number 73 | zhicheng
# processing record number 74 | nanchong
# processing record number 75 | kamenka
# processing record number 76 | arraial do cabo
# processing record number 77 | jaguarari
# processing record number 78 | rocha
# processing record number 79 | butaritari
# processing record number 80 | vao
# processing record number 81 | pakxe
# processing record number 82 | vuktyl
# processing record number 83 | puerto del rosario
# processing record number 84 | iqaluit
# processing record number 85 | tuktoyaktuk
# processing record number 86 | tarpon springs
# processing record number 87 | camacha
# processing record number 88 | lavrentiya
# processing record number 89 | biltine
# processing record number 90 | hermanus
# processing record number 91 | bredasdorp
# processing record number 92 | zastron
# processing record number 93 | qaanaaq
# processing record number 94 | malumfashi
# processing record number 95 | ribeira grande
# processing record number 96 | taseyevo
# processing record number 97 | kenai
# processing record number 98 | mahebourg
# processing record number 99 | cherskiy
# processing record number 100 | busselton
# processing record number 101 | grants
# processing record number 102 | katsuura
# City does not exist
# processing record number 103 | tiksi
# processing record number 104 | champerico
# processing record number 105 | kavieng
# processing record number 106 | matara
# processing record number 107 | beira
# processing record number 108 | brae
# processing record number 109 | khandyga
# processing record number 110 | maamba
# processing record number 111 | praia da vitoria
# processing record number 112 | margate
# processing record number 113 | high level
# processing record number 114 | isangel
# processing record number 115 | creetown
# processing record number 116 | qarqin
# processing record number 117 | rochegda
# processing record number 118 | pucallpa
# processing record number 119 | te anau
# processing record number 120 | muzhi
# City does not exist
# processing record number 121 | marovoay
# processing record number 122 | hithadhoo
# processing record number 123 | torbay
# processing record number 124 | bonavista
# processing record number 125 | cayenne
# processing record number 126 | kruisfontein
# processing record number 127 | bandarbeyla
# processing record number 128 | hirado
# City does not exist
# processing record number 129 | victoria
# processing record number 130 | visnes
# processing record number 131 | scottsbluff
# processing record number 132 | kamaishi
# processing record number 133 | teya
# City does not exist
# processing record number 134 | faanui
# processing record number 135 | pecos
# processing record number 136 | luderitz
# processing record number 137 | matagami
# processing record number 138 | ishigaki
# processing record number 139 | hualmay
# processing record number 140 | mount isa
# processing record number 141 | castro
# processing record number 142 | uni
# processing record number 143 | lincoln
# processing record number 144 | morgan city
# City does not exist
# processing record number 145 | provideniya
# processing record number 146 | sitka
# processing record number 147 | mengcheng
# processing record number 148 | nhulunbuy
# processing record number 149 | pimentel
# processing record number 150 | manokwari
# processing record number 151 | caravelas
# processing record number 152 | rincon
# processing record number 153 | quixeramobim
# processing record number 154 | dikson
# processing record number 155 | smiltene
# processing record number 156 | kidero
# processing record number 157 | kloulklubed
# City does not exist
# processing record number 158 | vila franca do campo
# processing record number 159 | los llanos de aridane
# processing record number 160 | caucaia
# processing record number 161 | turukhansk
# processing record number 162 | casablanca
# processing record number 163 | longyearbyen
# processing record number 164 | sangueya
# processing record number 165 | tateyama
# processing record number 166 | tromso
# processing record number 167 | fortuna
# processing record number 168 | payette
# City does not exist
# processing record number 169 | mar del plata
# processing record number 170 | parana
# processing record number 171 | umba
# processing record number 172 | san quintin
# processing record number 173 | flinders
# processing record number 174 | cockburn town
# processing record number 175 | lebu
# processing record number 176 | sayyan
# processing record number 177 | mezen
# processing record number 178 | luyang
# City does not exist
# processing record number 179 | nuuk
# processing record number 180 | chingirlau
# processing record number 181 | huarmey
# processing record number 182 | pemba
# processing record number 183 | sur
# processing record number 184 | prainha
# processing record number 185 | new norfolk
# processing record number 186 | port elizabeth
# processing record number 187 | sao jose da coroa grande
# processing record number 188 | belyy yar
# processing record number 189 | lao cai
# processing record number 190 | guerrero negro
# processing record number 191 | bambous virieux
# processing record number 192 | artyom
# processing record number 193 | lagoa
# processing record number 194 | marfino
# processing record number 195 | riyadh
# processing record number 196 | bengkulu
# processing record number 197 | hit
# processing record number 198 | clyde river
# processing record number 199 | kalmunai
# processing record number 200 | angoram
# processing record number 201 | tretten
# processing record number 202 | aksu
# processing record number 203 | campoverde
# processing record number 204 | port hedland
# processing record number 205 | zhoucheng
# processing record number 206 | port hardy
# processing record number 207 | gat
# processing record number 208 | balykshi
# processing record number 209 | aksehir
# processing record number 210 | ayorou
# processing record number 211 | namibe
# processing record number 212 | wilmington
# processing record number 213 | penzance
# processing record number 214 | viana
# City does not exist
# processing record number 215 | aklavik
# processing record number 216 | anadyr
# processing record number 217 | korla
# processing record number 218 | luanda
# processing record number 219 | richards bay
# processing record number 220 | port blair
# processing record number 221 | saint anthony
# processing record number 222 | sao filipe
# processing record number 223 | mujiayingzi
# processing record number 224 | sedan
# processing record number 225 | ponta do sol
# processing record number 226 | maracacume
# processing record number 227 | nelson bay
# processing record number 228 | ostrovnoy
# processing record number 229 | hami
# processing record number 230 | paracatu
# processing record number 231 | port shepstone
# processing record number 232 | hobyo
# processing record number 233 | hatillo
# City does not exist
# processing record number 234 | auki
# processing record number 235 | matay
# processing record number 236 | aras
# processing record number 237 | coihaique
# processing record number 238 | yumen
# City does not exist
# processing record number 239 | bubaque
# processing record number 240 | nome
# processing record number 241 | campina verde
# processing record number 242 | villa carlos paz
# processing record number 243 | krasnorechenskiy
# processing record number 244 | traralgon
# processing record number 245 | dunedin
# processing record number 246 | kaeo
# processing record number 247 | beringovskiy
# processing record number 248 | bojnurd
# processing record number 249 | sambava
# processing record number 250 | kortkeros
# City does not exist
# processing record number 251 | linkou
# processing record number 252 | severo-yeniseyskiy
# processing record number 253 | asau
# processing record number 254 | zhigansk
# processing record number 255 | vestmannaeyjar
# processing record number 256 | itapirapua
# processing record number 257 | grindavik
# processing record number 258 | el tocuyo
# processing record number 259 | fomboni
# processing record number 260 | zhanaozen
# processing record number 261 | punta alta
# processing record number 262 | garoua boulai
# processing record number 263 | pishin
# processing record number 264 | yar-sale
# processing record number 265 | bathsheba
# processing record number 266 | gouyave
# processing record number 267 | quelimane
# processing record number 268 | fairbanks
# processing record number 269 | saint-philippe
# processing record number 270 | kota kinabalu
# processing record number 271 | shache
# City does not exist
# processing record number 272 | maragogi
# processing record number 273 | obo
# processing record number 274 | alyangula
# processing record number 275 | itaituba
# processing record number 276 | necochea
# processing record number 277 | darhan
# processing record number 278 | westport
# processing record number 279 | yatou
# processing record number 280 | olafsvik
# processing record number 281 | praia
# processing record number 282 | severo-kurilsk
# processing record number 283 | great yarmouth
# processing record number 284 | piraju
# processing record number 285 | fairlie
# processing record number 286 | deputatskiy
# processing record number 287 | acajutla
# processing record number 288 | chiradzulu
# processing record number 289 | atar
# processing record number 290 | saldanha
# processing record number 291 | nara
# processing record number 292 | mogadishu
# processing record number 293 | garowe
# processing record number 294 | mayo
# processing record number 295 | akyab
# processing record number 296 | sorland
# processing record number 297 | khatanga
# processing record number 298 | havre-saint-pierre
# processing record number 299 | myaundzha
# processing record number 300 | voh
# processing record number 301 | nyrob
# processing record number 302 | port-gentil
# processing record number 303 | yichun
# processing record number 304 | adrar
# processing record number 305 | codajas
# City does not exist
# processing record number 306 | hamza
# processing record number 307 | chimbote
# processing record number 308 | padang
# processing record number 309 | moree
# processing record number 310 | redwater
# processing record number 311 | faya
# processing record number 312 | zhangye
# processing record number 313 | noumea
# processing record number 314 | klaksvik
# processing record number 315 | makaha
# processing record number 316 | tura
# processing record number 317 | ngawi
# processing record number 318 | varhaug
# processing record number 319 | pacific grove
# processing record number 320 | atikokan
# processing record number 321 | hofn
# processing record number 322 | thompson
# processing record number 323 | marsh harbour
# City does not exist
# processing record number 324 | dudinka
# processing record number 325 | mehamn
# processing record number 326 | buraydah
# processing record number 327 | muhos
# City does not exist
# processing record number 328 | kavaratti
# processing record number 329 | lucapa
# processing record number 330 | edson
# processing record number 331 | cururupu
# processing record number 332 | abbeville
# processing record number 333 | chuy
# processing record number 334 | cidreira
# processing record number 335 | akdepe
# processing record number 336 | nongstoin
# processing record number 337 | vostok
# processing record number 338 | kasongo-lunda
# processing record number 339 | uhlove
# processing record number 340 | laguna
# processing record number 341 | dongsheng
# processing record number 342 | narsaq
# processing record number 343 | weligama
# processing record number 344 | chara
# processing record number 345 | reconquista
# processing record number 346 | zemst
# processing record number 347 | tank
# processing record number 348 | lively
# processing record number 349 | belmonte
# processing record number 350 | kahului
# processing record number 351 | antofagasta
# City does not exist
# processing record number 352 | aykhal
# processing record number 353 | abu zabad
# City does not exist
# processing record number 354 | kichmengskiy gorodok
# processing record number 355 | nova olimpia
# processing record number 356 | seoul
# processing record number 357 | gwembe
# processing record number 358 | san cristobal
# processing record number 359 | ixtapa
# processing record number 360 | bumba
# processing record number 361 | bakchar
# processing record number 362 | mangai
# processing record number 363 | dalby
# processing record number 364 | xai-xai
# processing record number 365 | lorengau
# processing record number 366 | talara
# processing record number 367 | tari
# City does not exist
# processing record number 368 | buala
# processing record number 369 | onalaska
# processing record number 370 | beringen
# processing record number 371 | tautira
# processing record number 372 | novo oriente
# processing record number 373 | eagle pass
# processing record number 374 | bull savanna
# processing record number 375 | ilulissat
# processing record number 376 | leningradskiy
# processing record number 377 | springbok
# processing record number 378 | ipora
# processing record number 379 | abancay
# processing record number 380 | santa isabel
# processing record number 381 | poronaysk
# processing record number 382 | mulege
# processing record number 383 | fort nelson
# processing record number 384 | geraldton
# processing record number 385 | port hueneme
# processing record number 386 | tamworth
# City does not exist
# processing record number 387 | colares
# processing record number 388 | jaunpur
# processing record number 389 | thinadhoo
# processing record number 390 | bethel
# processing record number 391 | severodvinsk
# City does not exist
# City does not exist
# processing record number 392 | tigre
# processing record number 393 | gazli
# processing record number 394 | tukrah
# City does not exist
# City does not exist
# processing record number 395 | mount gambier
# processing record number 396 | akalgarh
# City does not exist
# processing record number 397 | acapulco
# City does not exist
# processing record number 398 | high rock
# processing record number 399 | tazmalt
# processing record number 400 | megion
# processing record number 401 | lasa
# processing record number 402 | loukhi
# processing record number 403 | acari
# processing record number 404 | aginskoye
# processing record number 405 | arman
# processing record number 406 | talnakh
# processing record number 407 | sosua
# processing record number 408 | lamu
# processing record number 409 | nuevo ideal
# processing record number 410 | plymouth
# processing record number 411 | hambantota
# processing record number 412 | ust-ilimsk
# processing record number 413 | lahaina
# processing record number 414 | viedma
# City does not exist
# processing record number 415 | belaya gora
# City does not exist
# processing record number 416 | grand gaube
# processing record number 417 | hauterive
# processing record number 418 | portobelo
# processing record number 419 | wonthaggi
# processing record number 420 | murdochville
# processing record number 421 | evanston
# City does not exist
# processing record number 422 | araouane
# processing record number 423 | xining
# processing record number 424 | pokhara
# processing record number 425 | porto recanati
# processing record number 426 | nyborg
# processing record number 427 | vaitape
# City does not exist
# processing record number 428 | alofi
# processing record number 429 | iquitos
# City does not exist
# processing record number 430 | saveh
# processing record number 431 | sao joao da barra
# processing record number 432 | upata
# processing record number 433 | quatre cocos
# processing record number 434 | souillac
# processing record number 435 | gizo
# processing record number 436 | mokobeng
# processing record number 437 | tommot
# processing record number 438 | galesong
# processing record number 439 | kalamata
# processing record number 440 | jalu
# processing record number 441 | churapcha
# processing record number 442 | wawa
# City does not exist
# processing record number 443 | touros
# processing record number 444 | panguna
# processing record number 445 | dubbo
# City does not exist
# processing record number 446 | goundam
# processing record number 447 | marinha grande
# processing record number 448 | warrington
# processing record number 449 | dawlatabad
# processing record number 450 | sibolga
# processing record number 451 | west bay
# processing record number 452 | karratha
# processing record number 453 | ahipara
# processing record number 454 | gurlan
# processing record number 455 | college
# processing record number 456 | lebyazhye
# processing record number 457 | meulaboh
# processing record number 458 | jiaocheng
# processing record number 459 | evensk
# processing record number 460 | dingle
# City does not exist
# processing record number 461 | marzuq
# processing record number 462 | mahibadhoo
# processing record number 463 | constantine
# processing record number 464 | erzin
# processing record number 465 | warri
# processing record number 466 | zvishavane
# processing record number 467 | henties bay
# processing record number 468 | vilani
# processing record number 469 | maraa
# processing record number 470 | genhe
# City does not exist
# processing record number 471 | tumen
# processing record number 472 | xingtai
# processing record number 473 | cascais
# processing record number 474 | borogontsy
# processing record number 475 | safford
# processing record number 476 | borba
# processing record number 477 | pitea
# processing record number 478 | poum
# processing record number 479 | pozo colorado
# processing record number 480 | taoudenni
# processing record number 481 | tokur
# processing record number 482 | newport
# processing record number 483 | santa vitoria do palmar
# processing record number 484 | verkhoyansk
# processing record number 485 | sampit
# processing record number 486 | kuusamo
# processing record number 487 | prince rupert
# processing record number 488 | lata
# processing record number 489 | ahuimanu
# processing record number 490 | yulara
# processing record number 491 | loandjili
# processing record number 492 | luganville
# processing record number 493 | piacabucu
# processing record number 494 | monki
# processing record number 495 | raton
# processing record number 496 | moose factory
# processing record number 497 | knyaginino
# processing record number 498 | kurumkan
# processing record number 499 | yenagoa
# processing record number 500 | rehoboth
# processing record number 501 | mae sot
# processing record number 502 | sinazongwe
# processing record number 503 | whitehorse
# processing record number 504 | cajati
# processing record number 505 | gribanovskiy
# processing record number 506 | homer
# processing record number 507 | moreira sales
# processing record number 508 | etchojoa
# processing record number 509 | chambersburg
# processing record number 510 | anori
# processing record number 511 | mackay
# processing record number 512 | taltal
# processing record number 513 | coquimbo
# processing record number 514 | presque isle
# processing record number 515 | haines junction
# processing record number 516 | gao
# processing record number 517 | wuan
# processing record number 518 | opunake
# processing record number 519 | saint-louis
# processing record number 520 | lyaskelya
# processing record number 521 | darnah
# processing record number 522 | rondonopolis
# processing record number 523 | bacolod
# City does not exist
# processing record number 524 | tiarei
# City does not exist
# processing record number 525 | khlevnoye
# processing record number 526 | kjopsvik
# processing record number 527 | okhotsk
# processing record number 528 | hervey bay
# processing record number 529 | biak
# processing record number 530 | laurel
# processing record number 531 | tchibanga
# processing record number 532 | puerto escondido
# processing record number 533 | eustis
# processing record number 534 | kirkconnel
# processing record number 535 | linfen
# processing record number 536 | regina
# processing record number 537 | marawi
# processing record number 538 | tres arroyos
# processing record number 539 | alihe
# processing record number 540 | gornopravdinsk
# processing record number 541 | ystad
# processing record number 542 | ballina
# processing record number 543 | chino valley
# processing record number 544 | broome
# processing record number 545 | sisimiut
# processing record number 546 | namatanai
# processing record number 547 | sarai
# City does not exist
# processing record number 548 | waingapu
# processing record number 549 | atambua
# processing record number 550 | naples
# processing record number 551 | qasigiannguit
# processing record number 552 | hasilpur
# processing record number 553 | porbandar
# processing record number 554 | barcelona
# City does not exist
# processing record number 555 | nioro
# processing record number 556 | codrington
# processing record number 557 | ust-kut
# processing record number 558 | cuamba
# processing record number 559 | kiknur

# %%
# Print out weather_response to identify the index for each item of the city_data
weather_response
# Out:
# {'coord': {'lon': 47.2, 'lat': 57.3},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 2.99,
#   'feels_like': -3.71,
#   'temp_min': 2.99,
#   'temp_max': 2.99,
#   'pressure': 1001,
#   'humidity': 89,
#   'sea_level': 1001,
#   'grnd_level': 988},
#  'visibility': 10000,
#  'wind': {'speed': 7.03, 'deg': 250},
#  'rain': {'1h': 0.9236000000000001},
#  'clouds': {'all': 100},
#  'dt': 1604799201,
#  'sys': {'country': 'RU', 'sunrise': 1604809137, 'sunset': 1604839862},
#  'timezone': 10800,
#  'id': 548747,
#  'name': 'Kiknur',
#  'cod': 200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert city_data to DataFrame
city_data = pd.DataFrame(city_data)
city_data

# Export the city data into a .csv 
city_data.to_csv(output_data_file, encoding="utf-8", index=False)
city_data
# Out:
#            City Country    DateTime  Humidity  Temperature  Max. Temp.  \
# 0          hilo      US  1604798838        88        22.63       24.00
# 1        nayoro      JP  1604799081        63         6.47        6.47
# 2        kodiak      US  1604798950        93         7.00        7.00
# 3        pueblo      US  1604799081        32        18.03       19.00
# 4       salalah      OM  1604799081        53        23.00       23.00
# ..          ...     ...         ...       ...          ...         ...
# 554       nioro      GM  1604799201        49        26.17       26.17
# 555  codrington      AU  1604799201        65        16.86       16.86
# 556     ust-kut      RU  1604799201        96        -4.16       -4.16
# 557      cuamba      MZ  1604799201        56        23.02       23.02
# 558      kiknur      RU  1604799201        89         2.99        2.99
#
#      Latitude  WindSpeed  Cloudiness  Longitude
# 0       19.73       2.10          90    -155.09
# 1       44.35       5.46          59     142.46
# 2       57.79       8.20          90    -152.41
# 3       38.25       9.80           1    -104.61
# 4       17.02       1.50           0      54.09
# ..        ...        ...         ...        ...
# 554     13.35       3.01           0     -15.75
# 555    -38.27       4.31           0     141.97
# 556     56.79       2.03         100     105.77
# 557    -14.80       3.36           0      36.54
# 558     57.30       7.03         100      47.20
#
# [559 rows x 10 columns]

# %%
# Print out the number of cities left after cleaning.
len(city_data)
# Out:
# 559

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Check the city_data for cities with humidity <= 100
clean_city_data = city_data.loc[(
    city_data["Humidity"] <= 100)]
clean_city_data

# The cities with humidity below or equal to 100 
# are still the same cities in our original datasets
# Out:
#            City Country    DateTime  Humidity  Temperature  Max. Temp.  \
# 0          hilo      US  1604798838        88        22.63       24.00
# 1        nayoro      JP  1604799081        63         6.47        6.47
# 2        kodiak      US  1604798950        93         7.00        7.00
# 3        pueblo      US  1604799081        32        18.03       19.00
# 4       salalah      OM  1604799081        53        23.00       23.00
# ..          ...     ...         ...       ...          ...         ...
# 554       nioro      GM  1604799201        49        26.17       26.17
# 555  codrington      AU  1604799201        65        16.86       16.86
# 556     ust-kut      RU  1604799201        96        -4.16       -4.16
# 557      cuamba      MZ  1604799201        56        23.02       23.02
# 558      kiknur      RU  1604799201        89         2.99        2.99
#
#      Latitude  WindSpeed  Cloudiness  Longitude
# 0       19.73       2.10          90    -155.09
# 1       44.35       5.46          59     142.46
# 2       57.79       8.20          90    -152.41
# 3       38.25       9.80           1    -104.61
# 4       17.02       1.50           0      54.09
# ..        ...        ...         ...        ...
# 554     13.35       3.01           0     -15.75
# 555    -38.27       4.31           0     141.97
# 556     56.79       2.03         100     105.77
# 557    -14.80       3.36           0      36.54
# 558     57.30       7.03         100      47.20
#
# [559 rows x 10 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
reduced_city_data = city_data.loc[(
    city_data["Humidity"] > 100)]
reduced_city_data.index

# There is no city with humidity>100.
# So, this step and the next step are skipped
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Retrieve the latitude and temperature from city_data
latitude = city_data["Latitude"].tolist()
latitude
temperature = city_data["Temperature"].tolist()
temperature

# Plot the scatter diagram of latitude vs. temperature
plt.scatter(latitude, temperature, color = "red")

# Include the axes labels, plot title, and date of analysis
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("City Latitude vs. Temperature (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure1.png")

# %% [markdown]
# #### What the lines of code in the previous cell achieve
# * The lines of codes in this cell generate the scatter plots of latitude VS.temperature in order to show how much a city's temperature is affected by its latitude.
# * The scatter plots show that there is a negative non-linear correlation between latitude and temperature. That is, an increase in latitude will result in a decrease in temperature.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Retrieve the humidity from city_data
humidity = city_data["Humidity"].tolist()
humidity

# Plot the scatter diagram of latitude vs. humidity
plt.scatter(latitude, humidity, color="yellowgreen")

# Include the axes labels, plot title, and date of analysis
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure2.png")

# %% [markdown]
# #### What the lines of code in the previous cell achieve
# * The lines of codes in this cell generate the scatter plots of latitude VS.humidity in order to show how much a city's humidity is affected by its latitude.
# * The scatter plots show that there is a positive correlation between latitude and humidity. That is, an increase in latitude will result in an increase in humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Retrieve the cloudiness from city_data
cloudiness = city_data["Cloudiness"].tolist()
cloudiness

# Plot the scatter diagram of latitude vs. cloudiness
plt.scatter(latitude, cloudiness, color="purple")

# Include the axes labels, plot title, and date of analysis
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure3.png")

# %% [markdown]
# #### What the lines of code in the previous cell achieve
# * The lines of codes in this cell generate the scatter plots of latitude VS.cloudiness in order to show how much a city's cloudiness is affected by its latitude.
# * The scatter plots show that there is no relationship between latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Retrieve the wind speed from city_data
windspeed = city_data["WindSpeed"].tolist()
windspeed

# Plot the scatter diagram of latitude vs. wind speed
plt.scatter(latitude, windspeed, color="brown")

# Include the axes labels, plot title, and date of analysis
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure4.png")

# %% [markdown]
# #### What the lines of code in the previous cell achieve
# * The lines of codes in this cell generate the scatter plots of latitude VS.wind speed in order to show how much a city's wind speed is affected by its latitude.
# * The scatter plots show that there is no relationship between latitude and wind speed.

# %% [markdown]
# ## Linear Regression

# %%
# Select data for Northern Hemisphere
North_city_data = city_data.loc[(
    city_data["Latitude"] >= 0)]
print(len(North_city_data))
North_city_data.head()
# Out:
# 374
#       City Country    DateTime  Humidity  Temperature  Max. Temp.  Latitude  \
# 0     hilo      US  1604798838        88        22.63       24.00     19.73
# 1   nayoro      JP  1604799081        63         6.47        6.47     44.35
# 2   kodiak      US  1604798950        93         7.00        7.00     57.79
# 3   pueblo      US  1604799081        32        18.03       19.00     38.25
# 4  salalah      OM  1604799081        53        23.00       23.00     17.02
#
#    WindSpeed  Cloudiness  Longitude
# 0       2.10          90    -155.09
# 1       5.46          59     142.46
# 2       8.20          90    -152.41
# 3       9.80           1    -104.61
# 4       1.50           0      54.09

# %%
# Select data for Southern Hemisphere
South_city_data = city_data.loc[(
    city_data["Latitude"] < 0)]
print(len(South_city_data))
South_city_data.head()
# Out:
# 185
#           City Country    DateTime  Humidity  Temperature  Max. Temp.  \
# 6      ushuaia      AR  1604799082        44        14.00       14.00
# 7    carnarvon      AU  1604798945        64        24.00       24.00
# 8   sundumbili      ZA  1604799082        93        19.00       19.00
# 9         soyo      AO  1604799082        85        25.20       25.20
# 10      sorong      ID  1604799083        72        29.61       29.61
#
#     Latitude  WindSpeed  Cloudiness  Longitude
# 6     -54.80       6.70          20     -68.30
# 7     -24.87       7.70          40     113.63
# 8     -29.13       1.00           0      31.40
# 9      -6.13       1.43          98      12.37
# 10     -0.88       4.11         100     131.25

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Retrieve the Max Temp and Latitude for northern hemisphere
Northmax_temp = North_city_data.iloc[:,5]
North_lat = North_city_data.iloc[:,6]

# Perform linear regression of Max Temp vs. Latitude
N_slope, N_int, N_r, N_p, N_std_err = linregress(Northmax_temp, North_lat)
N_fit = N_slope * Northmax_temp + N_int
print(N_fit)

# Print the regression equation
North_equation =  f"y={round(N_slope, 2)}x + {round(N_int,2)}"
print(North_equation)

# Compute and print the correlation 
print(f" Correlation =  {round((N_r),2)}") 

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
plt.plot(Northmax_temp, N_fit, color="red")
plt.annotate(North_equation,(-20,20), fontsize=12, color ="red")
plt.scatter(Northmax_temp, North_lat)

# Include the axes labels, plot title and date of analysis
plt.xlabel("Max Temp")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere: City Max Temp vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure5.png")
plt.show()
# Out:
# 0      23.549995
# 1      45.566118
# 2      44.900485
# 3      29.829551
# 4      24.805906
#          ...
# 552    21.841956
# 553    34.149885
# 554    20.824668
# 556    58.916453
# 558    49.936688
# Name: Max. Temp., Length: 374, dtype: float64
# y=-1.26x + 53.69
#  Correlation =  -0.86

# %% [markdown]
# #### What does the linear regression model?
#
# * The linear regression between max temperature and latitude of cities in the northern hemisphere is used to predict the latitudes of the cities given their max temperature.
# * There is a very strong negative relationship between max temperature and latitude. That is, the higher the max temperature the lower the latitude.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Retrieve the Max Temp and latitude for southern hemisphere
Southmax_temp = South_city_data.iloc[:,5]
South_lat = South_city_data.iloc[:,6]

# Perform linear regression of Max Temp vs. Latitude
S_slope, S_int, S_r, S_p, S_std_err = linregress(Southmax_temp, South_lat)
S_fit = S_slope * Southmax_temp + S_int
print(S_fit)

# Print the regression equation
South_equation =  f"y={round(S_slope, 2)}x + ({round(S_int,2)})"
print(South_equation)

# Compute and print the correlation 
print(f" Correlation =  {round((S_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(Southmax_temp, S_fit, color="red")
plt.annotate(South_equation,(20,-50), fontsize=12, color ="red")
plt.scatter(Southmax_temp, South_lat)
plt.xlabel("Max Temp")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere: City Max Temp vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure6.png")
plt.show()
# Out:
# 6     -33.064319
# 7     -17.934485
# 8     -25.499402
# 9     -16.118905
# 10     -9.446648
#          ...
# 545    -8.796066
# 547    -5.951657
# 548    -6.481201
# 555   -28.737186
# 557   -19.417209
# Name: Max. Temp., Length: 185, dtype: float64
# y=1.51x + (-54.25)
#  Correlation =  0.67

# %% [markdown]
# #### What does the linear regression model?
#
# * The linear regression between max temperature and latitude of cities in the southern hemisphere is used to predict the latitudes of the cities given their max temperature.
# * There is a moderate positive relationship between max temperature and latitude. That is, the higher the max temperature the higher the latitude.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Retrieve the humidity and latitude for northern hemisphere
North_city_data.head()
North_humidity = North_city_data.iloc[:,3]
North_lat = North_city_data.iloc[:,6]

# Perform linear regression of humidity vs. Latitude
NHL_slope, NHL_int, NHL_r, NHL_p, NHL_std_err = linregress(North_humidity, North_lat)
NHL_fit = NHL_slope * North_humidity + NHL_int
print(NHL_fit)

# Print the regression equation
NorthHL_equation =  f"y={round(NHL_slope, 2)}x + {round(NHL_int,2)}"
print(NorthHL_equation)

# Compute and print the correlation 
print(f" Correlation =  {round((NHL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(North_humidity, NHL_fit, color="red")
plt.annotate(NorthHL_equation,(20,70), fontsize=12, color ="red")
plt.scatter(North_humidity, North_lat)
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere: City Humidity vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure7.png")
plt.show()
# Out:
# 0      45.795033
# 1      37.360665
# 2      47.481907
# 3      26.902049
# 4      33.986918
#          ...
# 552    29.263672
# 553    49.843530
# 554    32.637419
# 556    48.494031
# 558    46.132408
# Name: Humidity, Length: 374, dtype: float64
# y=0.34x + 16.11
#  Correlation =  0.35

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between humidity and latitude of cities in the northern hemisphere is used to predict the latitudes of the cities given their humidity.
# * There is a weak positive relationship between humidity and latitude. That is, an increase in the humidity causes a slight increase in the latitude.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Retrieve the humidity for northern hemisphere
South_city_data.head()
South_humidity = South_city_data.iloc[:,3]
South_lat = South_city_data.iloc[:,6]

# Perform linear regression of humidity vs. Latitude
SHL_slope, SHL_int, SHL_r, SHL_p, SHL_std_err = linregress(South_humidity, South_lat)
SHL_fit = SHL_slope * South_humidity + SHL_int
print(SHL_fit)

# Print the regression equation
SouthHL_equation =  f"y={round(SHL_slope, 2)}x + ({round(SHL_int,2)})"
print(SouthHL_equation)

# Compute and print the correlation 
print(f" Correlation =  {round((SHL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(South_humidity, SHL_fit, color="red")
plt.annotate(SouthHL_equation,(20,-50), fontsize=12, color ="red")
plt.scatter(South_humidity, South_lat)
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere: City Humidity vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure8.png")
plt.show()
# Out:
# 6     -23.314731
# 7     -20.928358
# 8     -17.468116
# 9     -18.422665
# 10    -19.973808
#          ...
# 545   -20.809039
# 547   -23.195413
# 548   -23.911325
# 555   -20.809039
# 557   -21.882907
# Name: Humidity, Length: 185, dtype: float64
# y=0.12x + (-28.56)
#  Correlation =  0.18

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between humidity and latitude of cities in the Southern hemisphere is used to predict the latitudes of the cities given their humidity.
# * There is a weak positive relationship between humidity and latitude. That is, an increase in the humidity causes a slight increase in the latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Retrieve the cloudiness and Latitude for northern hemisphere
North_city_data.head()
North_cloud = North_city_data.iloc[:,8]
North_lat = North_city_data.iloc[:,6]

# Perform linear regression of cloudiness vs. Latitude
NCL_slope, NCL_int, NCL_r, NCL_p, NCL_std_err = linregress(North_cloud, North_lat)
NCL_fit = NCL_slope * North_cloud + NCL_int
print(NCL_fit)

# Print the regression equation
NorthCL_equation =  f"y={round(NCL_slope, 2)}x + {round(NCL_int,2)}"
print(NorthCL_equation)

# Compute and print the correlation 
print(f" Correlation = {round((NCL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(North_cloud, NCL_fit, color="red")
plt.annotate(NorthCL_equation,(20,70), fontsize=12, color ="red")
plt.scatter(North_cloud, North_lat)
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere: City Cloudiness vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure9.png")
plt.show()
# Out:
# 0      47.020269
# 1      42.698373
# 2      47.020269
# 3      34.612245
# 4      34.472829
#          ...
# 552    34.472829
# 553    34.472829
# 554    34.472829
# 556    48.414429
# 558    48.414429
# Name: Cloudiness, Length: 374, dtype: float64
# y=0.14x + 34.47
#  Correlation = 0.29

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between cloudiness and latitude of cities in the northern hemisphere is used to predict the latitudes of the cities given their cloudiness.
# * There is a weak positive relationship between cloudiness and latitude. That is, an increase in the cloudiness causes a slight increase in the latitude.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Retrieve the cloudiness and Latitude for northern hemisphere
South_city_data.head()
South_cloud = South_city_data.iloc[:,8]
South_lat = South_city_data.iloc[:,6]

# Perform linear regression of cloudiness vs. Latitude
SCL_slope, SCL_int, SCL_r, SCL_p, SCL_std_err = linregress(South_cloud, South_lat)
SCL_fit = SCL_slope * South_cloud + SCL_int
print(SCL_fit)

# Print the regression equation
SouthCL_equation =  f"y={round(SCL_slope, 2)}x + ({round(SCL_int,2)})"
print(SouthCL_equation)

# Compute and print the correlation
print(f" Correlation = {round((SCL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.annotate(SouthCL_equation,(10,-50), fontsize=12, color ="red")
plt.plot(South_cloud, SCL_fit, color="red")
plt.scatter(South_cloud, South_lat)
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere: City Cloudiness vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure10.png")
plt.show()
# Out:
# 6     -23.204139
# 7     -20.556665
# 8     -25.851613
# 9     -12.878990
# 10    -12.614243
#          ...
# 545   -21.086160
# 547   -18.571059
# 548   -24.395502
# 555   -25.851613
# 557   -25.851613
# Name: Cloudiness, Length: 185, dtype: float64
# y=0.13x + (-25.85)
#  Correlation = 0.39

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between cloudiness and latitude of cities in the southern hemisphere is used to predict the latitudes of the cities given their cloudiness.
# * There is a weak positive relationship between cloudiness and latitude. That is, an increase in the cloudiness causes a slight increase in the latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Retrieve the wind speed and Latitude for northern hemisphere
North_city_data.head()
North_windspeed = North_city_data.iloc[:,7]
North_lat = North_city_data.iloc[:,6]

# Perform linear regression of wind speed vs. Latitude
NWL_slope, NWL_int, NWL_r, NWL_p, NWL_std_err = linregress(North_windspeed, North_lat)
NWL_fit = NWL_slope * North_windspeed + NWL_int
print(NWL_fit)

# Print the regression equation
NorthWL_equation =  f"y={round(NWL_slope, 2)}x + {round(NWL_int,2)}"
print(NorthWL_equation)

# Compute and print the correlation 
print(f" Correlation = {round((NWL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(North_windspeed, NWL_fit, color="red")
plt.annotate(NorthWL_equation,(10,10), fontsize=12, color ="red")
plt.scatter(North_windspeed, North_lat)
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere: City Wind Speed vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure11.png")
plt.show()
# Out:
# 0      38.959889
# 1      43.424378
# 2      47.065063
# 3      49.191011
# 4      38.162658
#          ...
# 552    41.178846
# 553    40.288606
# 554    40.169021
# 556    38.866878
# 558    45.510464
# Name: WindSpeed, Length: 374, dtype: float64
# y=1.33x + 36.17
#  Correlation = 0.19

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between the wind speed and latitude of cities in the northern hemisphere is used to predict the latitudes of the cities given their wind speed.
# * There is a weak positive relationship between wind speed and latitude. That is, an increase in the wind speed causes a slight increase in the latitude.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Retrieve the wind speed and Latitude for southern hemisphere
South_city_data.head()
South_windspeed = South_city_data.iloc[:,7]
South_lat = South_city_data.iloc[:,6]

# Perform linear regression of wind speed vs. Latitude
SWL_slope, SWL_int, SWL_r, SWL_p, SWL_std_err = linregress(South_windspeed, South_lat)
SWL_fit = SWL_slope * South_windspeed + SWL_int
print(SWL_fit)

# Print the regression equation
SouthWL_equation =  f"y={round(SWL_slope, 2)}x + ({round(SWL_int,2)})"
print(SouthWL_equation)

# Compute and print the correlation 
print(f" Correlation = {round((SWL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(South_windspeed, SWL_fit, color="red")
plt.annotate(SouthWL_equation,(2,-50), fontsize=12, color ="red")
plt.scatter(South_windspeed, South_lat)
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere: City Wind Speed vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure12.png")
plt.show()
# Out:
# 6     -26.378330
# 7     -28.220777
# 8     -15.876382
# 9     -16.668634
# 10    -21.606392
#          ...
# 545   -15.673713
# 547   -20.390377
# 548   -16.189598
# 555   -21.974881
# 557   -20.224557
# Name: WindSpeed, Length: 185, dtype: float64
# y=-1.84x + (-14.03)
#  Correlation = -0.31

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between the wind speed and latitude of cities in the southern hemisphere is used to predict the latitudes of the cities given their wind speed.
# * There is a weak negative relationship between wind speed and latitude. That is, an increase in the wind speed causes a slight decrease in the latitude.
