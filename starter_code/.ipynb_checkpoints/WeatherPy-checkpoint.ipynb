# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ## Observations and Insights
#
# ### Analysis
#
# * On the overall, most cities analysed are from the northern hemisphere. That is, 398 of the 573 random cities selected when the code was last executed, belong to the northern hemisphere.
# *  With respect to the scatter plots, there is a negative non-linear correlation observed in the relationship between city's latitude and temperature, while there is a positive correlation between the city's latitude and humidity. This is understandable because most cities selected are from the northern hemisphere, and the temperature is expected to drop as we move towards the pole, while the humidity is expected to increase. However, there is no correlation observed in the relationships between city's latitude and cloudiness, and between city's latitude and the wind speed.
# *  With respect to linear regression, cities in both northern and southern hemispheres have strong correlation between max temperature and latitude, although the cities in the northern hemisphere have a negative correlation. This is understandable because generally around the world, it gets warmer towards the equator and cooler towards the poles.

# %%
# Import all dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json 
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Generate Cities List

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))

# Print Cities List
print(cities)
# Out:
# 618
# ['koungou', 'nago', 'norman wells', 'tabiauea', 'mariental', 'dzhebariki-khaya', 'yaan', 'arraial do cabo', 'barrow', 'ushuaia', 'mataura', 'busselton', 'saryshagan', 'lubao', 'amderma', 'tiksi', 'nikolskoye', 'acapulco', 'lorengau', 'butaritari', 'malwan', 'thomaston', 'krasnyy chikoy', 'kruisfontein', 'vaini', 'galle', 'tuatapere', 'barentsburg', 'hithadhoo', 'nan', 'berlevag', 'namwala', 'atuona', 'la ronge', 'bathsheba', 'dongli', 'taolanaro', 'les abymes', 'hermanus', 'nuuk', 'ribeira grande', 'benghazi', 'torbay', 'thompson', 'rikitea', 'saint-philippe', 'helong', 'albany', 'fort beaufort', 'souillac', 'dikson', 'ilhabela', 'jiuquan', 'hede', 'lompoc', 'ginir', 'salalah', 'whittlesea', 'ayan', 'cape town', 'puerto ayora', 'basco', 'mahebourg', 'hilo', 'kodiak', 'carnarvon', 'vardo', 'kapaa', 'yertsevo', 'bulgan', 'georgetown', 'marsala', 'airai', 'hobart', 'rocha', 'samalaeulu', 'phrae', 'atambua', 'ponta delgada', 'samusu', 'alofi', 'new norfolk', 'punta arenas', 'jamestown', 'quatre cocos', 'bluff', 'bredasdorp', 'tsihombe', 'nioro', 'naftah', 'ponta do sol', 'okoneshnikovo', 'sumbawa', 'sokoni', 'hobyo', 'laguna', 'tigre', 'periyanegamam', 'kamaishi', 'nizhneyansk', 'arona', 'trenton', 'azimur', 'sao felix do xingu', 'malim', 'ko samui', 'sosnovo-ozerskoye', 'marcona', 'hay river', 'hambantota', 'khatanga', 'high level', 'cidreira', 'klaksvik', 'sambava', 'karymskoye', 'lishu', 'port-gentil', 'yar-sale', 'sao filipe', 'trairi', 'atar', 'port blair', 'dori', 'carmelo', 'grand river south east', 'cherskiy', 'belyy yar', 'brae', 'maragogi', 'aklavik', 'pangnirtung', 'lagoa', 'katsuura', 'chardara', 'attawapiskat', 'vaitape', 'krasnovishersk', 'longyearbyen', 'iquitos', 'galiwinku', 'canyon', 'tagusao', 'yermish', 'kundiawa', 'yellowknife', 'tefe', 'mataram', 'batagay', 'coquimbo', 'isangel', 'fallon', 'morant bay', 'jiddah', 'madimba', 'hasaki', 'marawi', 'kamenskoye', 'seoul', 'inuvik', 'port elizabeth', 'faanui', 'jimenez', 'borogontsy', 'bandarbeyla', 'palabuhanratu', 'san patricio', 'sur', 'cockburn town', 'abu jubayhah', 'ilo', 'tuktoyaktuk', 'clyde river', 'asau', 'antofagasta', 'vaitupu', 'honningsvag', 'verkh-usugli', 'sitka', 'bengkulu', 'nanortalik', 'tasiilaq', 'yarim', 'diffa', 'balkanabat', 'venado tuerto', 'ilulissat', 'avarua', 'nurlat', 'neftekamsk', 'te anau', 'sherman', 'muli', 'ahipara', 'baoqing', 'grindavik', 'muisne', 'mar del plata', 'tabou', 'bolshaya rechka', 'phan rang', 'haines junction', 'poum', 'yichun', 'siverek', 'hit', 'bentiu', 'ofaqim', 'cesis', 'kampong chhnang', 'mangai', 'mys shmidta', 'geraldton', 'gidam', 'visimo-utkinsk', 'wattegama', 'flinders', 'lasem', 'gurlan', 'oriximina', 'bethel', 'port alfred', 'bambous virieux', 'victoria', 'batemans bay', 'gollere', 'tilichiki', 'esperance', 'bubaque', 'keti bandar', 'ola', 'aranos', 'tumannyy', 'chernyshevskiy', 'rawson', 'talnakh', 'mayo', 'tommot', 'soe', 'saint-denis', 'sarakhs', 'touros', 'east london', 'erzin', 'langenhagen', 'buchanan', 'galveston', 'kahului', 'juybar', 'baykit', 'taseyevo', 'kieta', 'castro', 'punakha', 'mount gambier', 'porto novo', 'kinablangan', 'qasigiannguit', 'suhbaatar', 'limbang', 'illoqqortoormiut', 'labutta', 'broken hill', 'ostrovnoy', 'san cristobal', 'cabo san lucas', 'sinkat', 'palmer', 'hofn', 'the valley', 'lahij', 'namatanai', 'jizan', 'san andres', 'miami', 'pacific grove', 'dudinka', 'camalu', 'bintulu', 'yelizovo', 'pevek', 'kpandae', 'beian', 'leningradskiy', 'inhambane', 'egvekinot', 'dauphin', 'kyren', 'harper', 'vanavara', 'noumea', 'hami', 'wasilla', 'roma', 'pangody', 'carndonagh', 'labytnangi', 'halalo', 'pangkalanbuun', 'hamilton', 'beni suef', 'gombong', 'araouane', 'vao', 'dunedin', 'narsaq', 'krapivinskiy', 'lebu', 'peniche', 'kalmunai', 'port lincoln', 'tevaitoa', 'moroto', 'qaanaaq', 'cruzeiro do sul', 'namibe', 'tornio', 'makakilo city', 'xam nua', 'mecca', 'aflu', 'kauhajoki', 'union', 'belushya guba', 'sentyabrskiy', 'uturoa', 'porto walter', 'lesogorskiy', 'ocos', 'srednekolyms ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Components of API 
city_data = []
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Initialize a counter to store the city number
counter = 1

# Perform a weather check 
# on each of the cities using a series of successive API calls
# Then, extract the weather components (latitude, temperature, wind speed..)
# needed for our analyses and charts
for city in cities:
    try:
        query_url = f"{url}&appid={weather_api_key}&units={units}&q={city}"
        weather_response = requests.get(query_url).json()
        city_humidity = weather_response["main"]["humidity"]
        city_temp = weather_response["main"]["temp"]
        city_Maxtemp = weather_response["main"]["temp_max"]
        city_lat = weather_response["coord"]["lat"] 
        city_wind = weather_response["wind"]["speed"]
        city_cloud = weather_response["clouds"]["all"]
        city_country = weather_response["sys"]["country"]
        city_datetime = weather_response["dt"]
        city_lon = weather_response["coord"]["lon"]
        # Print a log of each city with the city number and city name
        print(f"processing record number {counter} | {city}")
        counter += 1
        city_data.append ({"City":city,
                           "Country": city_country,
                           "DateTime":city_datetime,
                           "Humidity": city_humidity,
                           "Temperature": city_temp,
                           "Max. Temp.":  city_Maxtemp,
                           "Latitude": city_lat,
                           "WindSpeed": city_wind,
                           "Cloudiness": city_cloud,
                           "Longitude": city_lon
                     })        
    except:
        # Print city does not exist, if the city details are missing
        print("City does not exist")
        pass
# Out:
# processing record number 1 | koungou
# processing record number 2 | nago
# processing record number 3 | norman wells
# City does not exist
# processing record number 4 | mariental
# processing record number 5 | dzhebariki-khaya
# processing record number 6 | yaan
# processing record number 7 | arraial do cabo
# processing record number 8 | barrow
# processing record number 9 | ushuaia
# processing record number 10 | mataura
# processing record number 11 | busselton
# City does not exist
# processing record number 12 | lubao
# City does not exist
# processing record number 13 | tiksi
# processing record number 14 | nikolskoye
# processing record number 15 | acapulco
# processing record number 16 | lorengau
# processing record number 17 | butaritari
# City does not exist
# processing record number 18 | thomaston
# processing record number 19 | krasnyy chikoy
# processing record number 20 | kruisfontein
# processing record number 21 | vaini
# processing record number 22 | galle
# processing record number 23 | tuatapere
# City does not exist
# processing record number 24 | hithadhoo
# processing record number 25 | nan
# processing record number 26 | berlevag
# processing record number 27 | namwala
# processing record number 28 | atuona
# processing record number 29 | la ronge
# processing record number 30 | bathsheba
# processing record number 31 | dongli
# City does not exist
# processing record number 32 | les abymes
# processing record number 33 | hermanus
# processing record number 34 | nuuk
# processing record number 35 | ribeira grande
# processing record number 36 | benghazi
# processing record number 37 | torbay
# processing record number 38 | thompson
# processing record number 39 | rikitea
# processing record number 40 | saint-philippe
# processing record number 41 | helong
# processing record number 42 | albany
# processing record number 43 | fort beaufort
# processing record number 44 | souillac
# processing record number 45 | dikson
# processing record number 46 | ilhabela
# processing record number 47 | jiuquan
# processing record number 48 | hede
# processing record number 49 | lompoc
# processing record number 50 | ginir
# processing record number 51 | salalah
# processing record number 52 | whittlesea
# processing record number 53 | ayan
# processing record number 54 | cape town
# processing record number 55 | puerto ayora
# processing record number 56 | basco
# processing record number 57 | mahebourg
# processing record number 58 | hilo
# processing record number 59 | kodiak
# processing record number 60 | carnarvon
# processing record number 61 | vardo
# processing record number 62 | kapaa
# processing record number 63 | yertsevo
# processing record number 64 | bulgan
# processing record number 65 | georgetown
# processing record number 66 | marsala
# processing record number 67 | airai
# processing record number 68 | hobart
# processing record number 69 | rocha
# City does not exist
# processing record number 70 | phrae
# processing record number 71 | atambua
# processing record number 72 | ponta delgada
# City does not exist
# processing record number 73 | alofi
# processing record number 74 | new norfolk
# processing record number 75 | punta arenas
# processing record number 76 | jamestown
# processing record number 77 | quatre cocos
# processing record number 78 | bluff
# processing record number 79 | bredasdorp
# City does not exist
# processing record number 80 | nioro
# City does not exist
# processing record number 81 | ponta do sol
# processing record number 82 | okoneshnikovo
# City does not exist
# processing record number 83 | sokoni
# processing record number 84 | hobyo
# processing record number 85 | laguna
# processing record number 86 | tigre
# processing record number 87 | periyanegamam
# processing record number 88 | kamaishi
# City does not exist
# processing record number 89 | arona
# processing record number 90 | trenton
# City does not exist
# processing record number 91 | sao felix do xingu
# processing record number 92 | malim
# processing record number 93 | ko samui
# processing record number 94 | sosnovo-ozerskoye
# City does not exist
# processing record number 95 | hay river
# processing record number 96 | hambantota
# processing record number 97 | khatanga
# processing record number 98 | high level
# processing record number 99 | cidreira
# processing record number 100 | klaksvik
# processing record number 101 | sambava
# processing record number 102 | karymskoye
# processing record number 103 | lishu
# processing record number 104 | port-gentil
# processing record number 105 | yar-sale
# processing record number 106 | sao filipe
# processing record number 107 | trairi
# processing record number 108 | atar
# processing record number 109 | port blair
# processing record number 110 | dori
# processing record number 111 | carmelo
# City does not exist
# processing record number 112 | cherskiy
# processing record number 113 | belyy yar
# processing record number 114 | brae
# processing record number 115 | maragogi
# processing record number 116 | aklavik
# processing record number 117 | pangnirtung
# processing record number 118 | lagoa
# processing record number 119 | katsuura
# processing record number 120 | chardara
# City does not exist
# processing record number 121 | vaitape
# processing record number 122 | krasnovishersk
# processing record number 123 | longyearbyen
# processing record number 124 | iquitos
# City does not exist
# processing record number 125 | canyon
# processing record number 126 | tagusao
# processing record number 127 | yermish
# processing record number 128 | kundiawa
# processing record number 129 | yellowknife
# processing record number 130 | tefe
# processing record number 131 | mataram
# processing record number 132 | batagay
# processing record number 133 | coquimbo
# processing record number 134 | isangel
# processing record number 135 | fallon
# processing record number 136 | morant bay
# City does not exist
# processing record number 137 | madimba
# processing record number 138 | hasaki
# processing record number 139 | marawi
# City does not exist
# processing record number 140 | seoul
# processing record number 141 | inuvik
# processing record number 142 | port elizabeth
# processing record number 143 | faanui
# processing record number 144 | jimenez
# processing record number 145 | borogontsy
# processing record number 146 | bandarbeyla
# City does not exist
# processing record number 147 | san patricio
# processing record number 148 | sur
# processing record number 149 | cockburn town
# City does not exist
# processing record number 150 | ilo
# processing record number 151 | tuktoyaktuk
# processing record number 152 | clyde river
# processing record number 153 | asau
# processing record number 154 | antofagasta
# City does not exist
# processing record number 155 | honningsvag
# processing record number 156 | verkh-usugli
# processing record number 157 | sitka
# processing record number 158 | bengkulu
# processing record number 159 | nanortalik
# processing record number 160 | tasiilaq
# processing record number 161 | yarim
# processing record number 162 | diffa
# processing record number 163 | balkanabat
# processing record number 164 | venado tuerto
# processing record number 165 | ilulissat
# processing record number 166 | avarua
# processing record number 167 | nurlat
# processing record number 168 | neftekamsk
# processing record number 169 | te anau
# processing record number 170 | sherman
# processing record number 171 | muli
# processing record number 172 | ahipara
# processing record number 173 | baoqing
# processing record number 174 | grindavik
# processing record number 175 | muisne
# processing record number 176 | mar del plata
# processing record number 177 | tabou
# processing record number 178 | bolshaya rechka
# City does not exist
# processing record number 179 | haines junction
# processing record number 180 | poum
# processing record number 181 | yichun
# processing record number 182 | siverek
# processing record number 183 | hit
# processing record number 184 | bentiu
# processing record number 185 | ofaqim
# processing record number 186 | cesis
# processing record number 187 | kampong chhnang
# processing record number 188 | mangai
# City does not exist
# processing record number 189 | geraldton
# processing record number 190 | gidam
# City does not exist
# processing record number 191 | wattegama
# processing record number 192 | flinders
# processing record number 193 | lasem
# processing record number 194 | gurlan
# processing record number 195 | oriximina
# processing record number 196 | bethel
# processing record number 197 | port alfred
# processing record number 198 | bambous virieux
# processing record number 199 | victoria
# processing record number 200 | batemans bay
# City does not exist
# processing record number 201 | tilichiki
# processing record number 202 | esperance
# processing record number 203 | bubaque
# processing record number 204 | keti bandar
# processing record number 205 | ola
# processing record number 206 | aranos
# City does not exist
# processing record number 207 | chernyshevskiy
# processing record number 208 | rawson
# processing record number 209 | talnakh
# processing record number 210 | mayo
# processing record number 211 | tommot
# processing record number 212 | soe
# processing record number 213 | saint-denis
# processing record number 214 | sarakhs
# processing record number 215 | touros
# processing record number 216 | east london
# processing record number 217 | erzin
# processing record number 218 | langenhagen
# processing record number 219 | buchanan
# processing record number 220 | galveston
# processing record number 221 | kahului
# processing record number 222 | juybar
# processing record number 223 | baykit
# processing record number 224 | taseyevo
# processing record number 225 | kieta
# processing record number 226 | castro
# processing record number 227 | punakha
# processing record number 228 | mount gambier
# processing record number 229 | porto novo
# processing record number 230 | kinablangan
# processing record number 231 | qasigiannguit
# processing record number 232 | suhbaatar
# processing record number 233 | limbang
# City does not exist
# City does not exist
# processing record number 234 | broken hill
# processing record number 235 | ostrovnoy
# processing record number 236 | san cristobal
# processing record number 237 | cabo san lucas
# City does not exist
# processing record number 238 | palmer
# processing record number 239 | hofn
# processing record number 240 | the valley
# processing record number 241 | lahij
# processing record number 242 | namatanai
# processing record number 243 | jizan
# processing record number 244 | san andres
# processing record number 245 | miami
# processing record number 246 | pacific grove
# processing record number 247 | dudinka
# processing record number 248 | camalu
# processing record number 249 | bintulu
# processing record number 250 | yelizovo
# processing record number 251 | pevek
# processing record number 252 | kpandae
# processing record number 253 | beian
# processing record number 254 | leningradskiy
# processing record number 255 | inhambane
# processing record number 256 | egvekinot
# processing record number 257 | dauphin
# processing record number 258 | kyren
# processing record number 259 | harper
# processing record number 260 | vanavara
# processing record number 261 | noumea
# processing record number 262 | hami
# processing record number 263 | wasilla
# processing record number 264 | roma
# processing record number 265 | pangody
# processing record number 266 | carndonagh
# processing record number 267 | labytnangi
# City does not exist
# processing record number 268 | pangkalanbuun
# processing record number 269 | hamilton
# processing record number 270 | beni suef
# processing record number 271 | gombong
# processing record number 272 | araouane
# processing record number 273 | vao
# processing record number 274 | dunedin
# processing record number 275 | narsaq
# processing record number 276 | krapivinskiy
# processing record number 277 | lebu
# processing record number 278 | peniche
# processing record number 279 | kalmunai
# processing record number 280 | port lincoln
# processing record number 281 | tevaitoa
# processing record number 282 | moroto
# processing record number 283 | qaanaaq
# processing record number 284 | cruzeiro do sul
# processing record number 285 | namibe
# processing record number 286 | tornio
# processing record number 287 | makakilo city
# processing record number 288 | xam nua
# processing record number 289 | mecca
# City does not exist
# processing record number 290 | kauhajoki
# processing record number 291 | union
# City does not exist
# City does not exist
# processing record number 292 | uturoa
# processing record number 293 | porto walter
# processing record number 294 | lesogorskiy
# processing record number 295 | ocos
# processing record number 296 | srednekolymsk
# processing record number 297 | yantarnyy
# processing record number 298 | koslan
# processing record number 299 | guia de isora
# processing record number 300 | mascote
# City does not exist
# processing record number 301 | vung tau
# processing record number 302 | kargasok
# processing record number 303 | kegums
# processing record number 304 | baillif
# processing record number 305 | tarko-sale
# processing record number 306 | milledgeville
# processing record number 307 | lalganj
# processing record number 308 | ritchie
# processing record number 309 | mumford
# processing record number 310 | newport
# processing record number 311 | semey
# processing record number 312 | gberia fotombu
# processing record number 313 | mkushi
# processing record number 314 | tosya
# processing record number 315 | zaterechnyy
# processing record number 316 | vostok
# processing record number 317 | yulara
# processing record number 318 | ginda
# processing record number 319 | say
# processing record number 320 | chokurdakh
# processing record number 321 | talaya
# processing record number 322 | acajutla
# processing record number 323 | palmas bellas
# processing record number 324 | padang
# processing record number 325 | manjakandriana
# processing record number 326 | mount isa
# processing record number 327 | praya
# processing record number 328 | praia da vitoria
# processing record number 329 | bell ville
# processing record number 330 | suihua
# processing record number 331 | adre
# processing record number 332 | ambilobe
# processing record number 333 | belaya kholunitsa
# processing record number 334 | samur
# processing record number 335 | pauini
# processing record number 336 | naryan-mar
# processing record number 337 | farah
# processing record number 338 | cerrito
# processing record number 339 | kautokeino
# processing record number 340 | aswan
# processing record number 341 | saint anthony
# processing record number 342 | along
# processing record number 343 | waipawa
# processing record number 344 | bitung
# processing record number 345 | bilma
# processing record number 346 | auki
# processing record number 347 | grand-santi
# processing record number 348 | khakhea
# processing record number 349 | dauriya
# processing record number 350 | ordynskoye
# processing record number 351 | nouadhibou
# processing record number 352 | praia
# processing record number 353 | brigantine
# processing record number 354 | iranshahr
# processing record number 355 | sumbe
# City does not exist
# processing record number 356 | fairbanks
# processing record number 357 | santa ana
# processing record number 358 | ust-nera
# processing record number 359 | dukat
# processing record number 360 | sterling
# processing record number 361 | lasa
# processing record number 362 | marzuq
# processing record number 363 | merauke
# processing record number 364 | turbat
# processing record number 365 | alice springs
# processing record number 366 | chuy
# processing record number 367 | pitimbu
# processing record number 368 | tibu
# processing record number 369 | venancio aires
# processing record number 370 | denpasar
# processing record number 371 | kulhudhuffushi
# processing record number 372 | baijiantan
# processing record number 373 | evensk
# processing record number 374 | voitsberg
# processing record number 375 | portland
# processing record number 376 | villamontes
# processing record number 377 | flin flon
# processing record number 378 | minab
# processing record number 379 | mancio lima
# processing record number 380 | umea
# processing record number 381 | guerrero negro
# processing record number 382 | lao cai
# City does not exist
# processing record number 383 | lata
# processing record number 384 | tambopata
# processing record number 385 | marrakesh
# processing record number 386 | spearfish
# processing record number 387 | kenai
# processing record number 388 | benguela
# processing record number 389 | viedma
# processing record number 390 | kokkola
# processing record number 391 | saldanha
# processing record number 392 | saskylakh
# processing record number 393 | road town
# processing record number 394 | jardim
# processing record number 395 | westport
# City does not exist
# processing record number 396 | aldama
# processing record number 397 | felanitx
# processing record number 398 | guangyuan
# processing record number 399 | pachino
# processing record number 400 | faya
# processing record number 401 | petrokamenskoye
# processing record number 402 | soyo
# processing record number 403 | havre-saint-pierre
# processing record number 404 | ashcroft
# processing record number 405 | conakry
# processing record number 406 | birao
# processing record number 407 | provideniya
# processing record number 408 | meridian
# processing record number 409 | yangambi
# processing record number 410 | lavrentiya
# processing record number 411 | mariestad
# processing record number 412 | moranbah
# processing record number 413 | san quintin
# processing record number 414 | lahad datu
# processing record number 415 | olinda
# processing record number 416 | trelew
# City does not exist
# processing record number 417 | kaitangata
# processing record number 418 | kungurtug
# processing record number 419 | chissamba
# processing record number 420 | shizilu
# processing record number 421 | sorong
# processing record number 422 | luderitz
# processing record number 423 | mareeba
# processing record number 424 | acarau
# processing record number 425 | banswada
# processing record number 426 | asotthalom
# processing record number 427 | khorramabad
# processing record number 428 | toppenish
# processing record number 429 | madang
# processing record number 430 | cascais
# processing record number 431 | tahe
# processing record number 432 | huarmey
# processing record number 433 | warmbad
# processing record number 434 | akhmeta
# processing record number 435 | khani
# processing record number 436 | la romana
# processing record number 437 | lengshuijiang
# processing record number 438 | george
# processing record number 439 | thunder bay
# processing record number 440 | alpena
# processing record number 441 | iskateley
# processing record number 442 | gamba
# processing record number 443 | china
# processing record number 444 | tual
# processing record number 445 | shelburne
# processing record number 446 | otofuke
# processing record number 447 | merritt
# processing record number 448 | calvinia
# processing record number 449 | vila velha
# processing record number 450 | sao joao da barra
# City does not exist
# processing record number 451 | ballina
# processing record number 452 | balastya
# processing record number 453 | sioux lookout
# processing record number 454 | takoradi
# processing record number 455 | bireun
# City does not exist
# processing record number 456 | crib point
# processing record number 457 | kvarkeno
# processing record number 458 | saint-joseph
# processing record number 459 | gaildorf
# processing record number 460 | smidovich
# processing record number 461 | ushtobe
# processing record number 462 | batesville
# processing record number 463 | ouadda
# processing record number 464 | vila franca do campo
# processing record number 465 | avera
# processing record number 466 | carbonia
# processing record number 467 | matamoros
# processing record number 468 | valle de allende
# processing record number 469 | marsh harbour
# City does not exist
# processing record number 470 | caiaponia
# processing record number 471 | maputo
# processing record number 472 | cayenne
# processing record number 473 | nadym
# processing record number 474 | aksay
# processing record number 475 | jiangmen
# processing record number 476 | upernavik
# processing record number 477 | mitsamiouli
# processing record number 478 | udachnyy
# processing record number 479 | cairns
# processing record number 480 | ancud
# processing record number 481 | severo-kurilsk
# processing record number 482 | stelle
# processing record number 483 | chimoio
# processing record number 484 | mabaruma
# processing record number 485 | behbahan
# processing record number 486 | evanston
# processing record number 487 | alamos
# City does not exist
# processing record number 488 | coxim
# processing record number 489 | labuhan
# processing record number 490 | rockland
# processing record number 491 | florence
# processing record number 492 | naze
# processing record number 493 | nizwa
# processing record number 494 | emerald
# processing record number 495 | maryborough
# processing record number 496 | maningrida
# processing record number 497 | greenville
# processing record number 498 | ormara
# processing record number 499 | iqaluit
# processing record number 500 | malatya
# processing record number 501 | le port
# processing record number 502 | saint george
# processing record number 503 | port moresby
# processing record number 504 | bendigo
# City does not exist
# processing record number 505 | ewo
# processing record number 506 | begamganj
# processing record number 507 | sabang
# processing record number 508 | shimoda
# processing record number 509 | eydhafushi
# processing record number 510 | sarahan
# processing record number 511 | beyneu
# processing record number 512 | dingle
# processing record number 513 | sudova vyshnya
# processing record number 514 | chumikan
# processing record number 515 | pilar
# processing record number 516 | enshi
# processing record number 517 | nova vicosa
# processing record number 518 | kaffrine
# processing record number 519 | campbellton
# processing record number 520 | teguise
# processing record number 521 | tahoua
# processing record number 522 | taoudenni
# processing record number 523 | tamiahua
# processing record number 524 | nishihara
# processing record number 525 | nantucket
# processing record number 526 | karratha
# processing record number 527 | mpulungu
# processing record number 528 | san policarpo
# processing record number 529 | yasothon
# processing record number 530 | kurumkan
# processing record number 531 | beloha
# processing record number 532 | manokwari
# processing record number 533 | meulaboh
# processing record number 534 | sinnamary
# processing record number 535 | kavaratti
# processing record number 536 | mehamn
# processing record number 537 | kokopo
# processing record number 538 | toropets
# processing record number 539 | necochea
# processing record number 540 | wamba
# processing record number 541 | sept-iles
# processing record number 542 | olathe
# City does not exist
# processing record number 543 | chimbote
# processing record number 544 | buala
# processing record number 545 | kavieng
# processing record number 546 | chapleau
# processing record number 547 | mazagao
# processing record number 548 | ust-tarka
# processing record number 549 | nynashamn
# processing record number 550 | mawlaik
# processing record number 551 | outlook
# processing record number 552 | los llanos de aridane
# processing record number 553 | xuanhua
# processing record number 554 | ugoofaaru
# processing record number 555 | buzuluk
# processing record number 556 | novoagansk
# processing record number 557 | yanam
# processing record number 558 | kashira
# processing record number 559 | vila
# processing record number 560 | tadine
# processing record number 561 | manuk mangkaw
# processing record number 562 | abu samrah
# processing record number 563 | kedrovyy
# processing record number 564 | tshikapa
# processing record number 565 | singaraja
# processing record number 566 | broome
# processing record number 567 | hun
# processing record number 568 | arroyo
# processing record number 569 | leh
# processing record number 570 | kolpashevo
# processing record number 571 | paracuru
# processing record number 572 | taga
# processing record number 573 | biloela

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert city_data to DataFrame
city_data = pd.DataFrame(city_data)
city_data

# Export the city data into a .csv 
city_data.to_csv(output_data_file, encoding="utf-8", index=False)
city_data
# Out:
#                  City Country    DateTime  Humidity  Temperature  Max. Temp.  \
# 0             koungou      YT  1604799450        88        25.00       25.00
# 1                nago      JP  1604799451        83        26.89       27.00
# 2        norman wells      CA  1604799087        92        -2.00       -2.00
# 3           mariental      NA  1604799451        55        14.96       14.96
# 4    dzhebariki-khaya      RU  1604799451        87       -20.56      -20.56
# ..                ...     ...         ...       ...          ...         ...
# 568               leh      IN  1604799487        57        -1.77       -1.77
# 569        kolpashevo      RU  1604799573        83         2.26        2.26
# 570          paracuru      BR  1604799573        78        27.00       27.00
# 571              taga      RO  1604799573       100         2.00        2.00
# 572           biloela      AU  1604799573        38        28.31       28.31
#
#      Latitude  WindSpeed  Cloudiness  Longitude
# 0      -12.73       1.78          75      45.20
# 1       26.59       2.60          75     127.98
# 2       65.28       1.50          75    -126.83
# 3      -24.63       2.72           0      17.97
# 4       62.22       0.66          97     135.80
# ..        ...        ...         ...        ...
# 568     34.17       2.08           0      77.58
# 569     58.31       5.44          99      82.91
# 570     -3.41       4.10          20     -39.03
# 571     46.95       0.50          90      24.05
# 572    -24.42       5.88          91     150.50
#
# [573 rows x 10 columns]

# %%
# Print out the number of cities left after cleaning.
len(city_data)
# Out:
# 573

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Check the city_data for cities with humidity <= 100
clean_city_data = city_data.loc[(
    city_data["Humidity"] <= 100)]
clean_city_data

# The cities with humidity below or equal to 100 
# are still the same cities in our original datasets
# Out:
#                  City Country    DateTime  Humidity  Temperature  Max. Temp.  \
# 0             koungou      YT  1604799450        88        25.00       25.00
# 1                nago      JP  1604799451        83        26.89       27.00
# 2        norman wells      CA  1604799087        92        -2.00       -2.00
# 3           mariental      NA  1604799451        55        14.96       14.96
# 4    dzhebariki-khaya      RU  1604799451        87       -20.56      -20.56
# ..                ...     ...         ...       ...          ...         ...
# 568               leh      IN  1604799487        57        -1.77       -1.77
# 569        kolpashevo      RU  1604799573        83         2.26        2.26
# 570          paracuru      BR  1604799573        78        27.00       27.00
# 571              taga      RO  1604799573       100         2.00        2.00
# 572           biloela      AU  1604799573        38        28.31       28.31
#
#      Latitude  WindSpeed  Cloudiness  Longitude
# 0      -12.73       1.78          75      45.20
# 1       26.59       2.60          75     127.98
# 2       65.28       1.50          75    -126.83
# 3      -24.63       2.72           0      17.97
# 4       62.22       0.66          97     135.80
# ..        ...        ...         ...        ...
# 568     34.17       2.08           0      77.58
# 569     58.31       5.44          99      82.91
# 570     -3.41       4.10          20     -39.03
# 571     46.95       0.50          90      24.05
# 572    -24.42       5.88          91     150.50
#
# [573 rows x 10 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
reduced_city_data = city_data.loc[(
    city_data["Humidity"] > 100)]
reduced_city_data.index

# There is no city with humidity>100.
# So, this step and the next step are skipped
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Retrieve the latitude and temperature from city_data
latitude = city_data["Latitude"].tolist()
latitude
temperature = city_data["Temperature"].tolist()
temperature

# Plot the scatter diagram of latitude vs. temperature
plt.scatter(latitude, temperature, color = "red")

# Include the axes labels, plot title, and date of analysis
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("City Latitude vs. Temperature (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure1.png")

# %% [markdown]
# #### What the lines of code in the previous cell achieve
# * The lines of codes in this cell generate the scatter plots of latitude VS.temperature in order to show how much a city's temperature is affected by its latitude.
# * The scatter plots show that there is a negative non-linear correlation between latitude and temperature. That is, an increase in latitude will result in a decrease in temperature.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Retrieve the humidity from city_data
humidity = city_data["Humidity"].tolist()
humidity

# Plot the scatter diagram of latitude vs. humidity
plt.scatter(latitude, humidity, color="yellowgreen")

# Include the axes labels, plot title, and date of analysis
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure2.png")

# %% [markdown]
# #### What the lines of code in the previous cell achieve
# * The lines of codes in this cell generate the scatter plots of latitude VS.humidity in order to show how much a city's humidity is affected by its latitude.
# * The scatter plots show that there is a positive correlation between latitude and humidity. That is, an increase in latitude will result in an increase in humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Retrieve the cloudiness from city_data
cloudiness = city_data["Cloudiness"].tolist()
cloudiness

# Plot the scatter diagram of latitude vs. cloudiness
plt.scatter(latitude, cloudiness, color="purple")

# Include the axes labels, plot title, and date of analysis
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure3.png")

# %% [markdown]
# #### What the lines of code in the previous cell achieve
# * The lines of codes in this cell generate the scatter plots of latitude VS.cloudiness in order to show how much a city's cloudiness is affected by its latitude.
# * The scatter plots show that there is no relationship between latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Retrieve the wind speed from city_data
windspeed = city_data["WindSpeed"].tolist()
windspeed

# Plot the scatter diagram of latitude vs. wind speed
plt.scatter(latitude, windspeed, color="brown")

# Include the axes labels, plot title, and date of analysis
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure4.png")

# %% [markdown]
# #### What the lines of code in the previous cell achieve
# * The lines of codes in this cell generate the scatter plots of latitude VS.wind speed in order to show how much a city's wind speed is affected by its latitude.
# * The scatter plots show that there is no relationship between latitude and wind speed.

# %% [markdown]
# ## Linear Regression

# %%
# Select data for Northern Hemisphere
North_city_data = city_data.loc[(
    city_data["Latitude"] >= 0)]
print(len(North_city_data))
North_city_data.head()
# Out:
# 398
#                City Country    DateTime  Humidity  Temperature  Max. Temp.  \
# 1              nago      JP  1604799451        83        26.89       27.00
# 2      norman wells      CA  1604799087        92        -2.00       -2.00
# 4  dzhebariki-khaya      RU  1604799451        87       -20.56      -20.56
# 5              yaan      NG  1604799452        75        23.11       23.11
# 7            barrow      US  1604799095        86        -1.00       -1.00
#
#    Latitude  WindSpeed  Cloudiness  Longitude
# 1     26.59       2.60          75     127.98
# 2     65.28       1.50          75    -126.83
# 4     62.22       0.66          97     135.80
# 5      7.38       1.89          53       8.57
# 7     71.29      10.30          90    -156.79

# %%
# Select data for Southern Hemisphere
South_city_data = city_data.loc[(
    city_data["Latitude"] < 0)]
print(len(South_city_data))
South_city_data.head()
# Out:
# 175
#               City Country    DateTime  Humidity  Temperature  Max. Temp.  \
# 0          koungou      YT  1604799450        88        25.00       25.00
# 3        mariental      NA  1604799451        55        14.96       14.96
# 6  arraial do cabo      BR  1604799097        79        22.41       22.41
# 8          ushuaia      AR  1604799082        44        14.00       14.00
# 9          mataura      NZ  1604799083        52        12.22       12.22
#
#    Latitude  WindSpeed  Cloudiness  Longitude
# 0    -12.73       1.78          75      45.20
# 3    -24.63       2.72           0      17.97
# 6    -22.97       4.10          99     -42.03
# 8    -54.80       6.70          20     -68.30
# 9    -46.19       4.92           0     168.86

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Retrieve the Max Temp and Latitude for northern hemisphere
Northmax_temp = North_city_data.iloc[:,5]
North_lat = North_city_data.iloc[:,6]

# Perform linear regression of Max Temp vs. Latitude
N_slope, N_int, N_r, N_p, N_std_err = linregress(Northmax_temp, North_lat)
N_fit = N_slope * Northmax_temp + N_int
print(N_fit)

# Print the regression equation
North_equation =  f"y={round(N_slope, 2)}x + {round(N_int,2)}"
print(North_equation)

# Compute and print the correlation 
print(f" Correlation =  {round((N_r),2)}") 

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
plt.plot(Northmax_temp, N_fit, color="red")
plt.annotate(North_equation,(-20,20), fontsize=12, color ="red")
plt.scatter(Northmax_temp, North_lat)

# Include the axes labels, plot title and date of analysis
plt.xlabel("Max Temp")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere: City Max Temp vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure5.png")
plt.show()
# Out:
# 1      16.717739
# 2      55.300090
# 4      79.992795
# 5      21.893096
# 7      53.969664
#          ...
# 566    34.891357
# 567    41.556791
# 568    54.994092
# 569    49.632476
# 571    49.978387
# Name: Max. Temp., Length: 398, dtype: float64
# y=-1.33x + 52.64
#  Correlation =  -0.88

# %% [markdown]
# #### What does the linear regression model?
#
# * The linear regression between max temperature and latitude of cities in the northern hemisphere is used to predict the latitudes of the cities given their max temperature.
# * There is a very strong negative relationship between max temperature and latitude. That is, the higher the max temperature the lower the latitude.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Retrieve the Max Temp and latitude for southern hemisphere
Southmax_temp = South_city_data.iloc[:,5]
South_lat = South_city_data.iloc[:,6]

# Perform linear regression of Max Temp vs. Latitude
S_slope, S_int, S_r, S_p, S_std_err = linregress(Southmax_temp, South_lat)
S_fit = S_slope * Southmax_temp + S_int
print(S_fit)

# Print the regression equation
South_equation =  f"y={round(S_slope, 2)}x + ({round(S_int,2)})"
print(South_equation)

# Compute and print the correlation 
print(f" Correlation =  {round((S_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(Southmax_temp, S_fit, color="red")
plt.annotate(South_equation,(20,-50), fontsize=12, color ="red")
plt.scatter(Southmax_temp, South_lat)
plt.xlabel("Max Temp")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere: City Max Temp vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure6.png")
plt.show()
# Out:
# 0     -16.406244
# 3     -32.846296
# 6     -20.647253
# 8     -34.418253
# 9     -37.332923
#          ...
# 559   -15.800385
# 563   -23.430927
# 564    -6.696134
# 570   -13.131333
# 572   -10.986267
# Name: Max. Temp., Length: 175, dtype: float64
# y=1.64x + (-57.34)
#  Correlation =  0.73

# %% [markdown]
# #### What does the linear regression model?
#
# * The linear regression between max temperature and latitude of cities in the southern hemisphere is used to predict the latitudes of the cities given their max temperature.
# * There is a strong positive relationship between max temperature and latitude. That is, the higher the max temperature the higher the latitude.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Retrieve the humidity and latitude for northern hemisphere
North_city_data.head()
North_humidity = North_city_data.iloc[:,3]
North_lat = North_city_data.iloc[:,6]

# Perform linear regression of humidity vs. Latitude
NHL_slope, NHL_int, NHL_r, NHL_p, NHL_std_err = linregress(North_humidity, North_lat)
NHL_fit = NHL_slope * North_humidity + NHL_int
print(NHL_fit)

# Print the regression equation
NorthHL_equation =  f"y={round(NHL_slope, 2)}x + {round(NHL_int,2)}"
print(NorthHL_equation)

# Compute and print the correlation 
print(f" Correlation =  {round((NHL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(North_humidity, NHL_fit, color="red")
plt.annotate(NorthHL_equation,(20,70), fontsize=12, color ="red")
plt.scatter(North_humidity, North_lat)
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere: City Humidity vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure7.png")
plt.show()
# Out:
# 1      40.272966
# 2      42.937402
# 4      41.457160
# 5      37.904579
# 7      41.161111
#          ...
# 566    43.233450
# 567    43.233450
# 568    32.575708
# 569    40.272966
# 571    45.305789
# Name: Humidity, Length: 398, dtype: float64
# y=0.3x + 15.7
#  Correlation =  0.27

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between humidity and latitude of cities in the northern hemisphere is used to predict the latitudes of the cities given their humidity.
# * There is a weak positive relationship between humidity and latitude. That is, an increase in the humidity causes a slight increase in the latitude.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Retrieve the humidity for northern hemisphere
South_city_data.head()
South_humidity = South_city_data.iloc[:,3]
South_lat = South_city_data.iloc[:,6]

# Perform linear regression of humidity vs. Latitude
SHL_slope, SHL_int, SHL_r, SHL_p, SHL_std_err = linregress(South_humidity, South_lat)
SHL_fit = SHL_slope * South_humidity + SHL_int
print(SHL_fit)

# Print the regression equation
SouthHL_equation =  f"y={round(SHL_slope, 2)}x + ({round(SHL_int,2)})"
print(SouthHL_equation)

# Compute and print the correlation 
print(f" Correlation =  {round((SHL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(South_humidity, SHL_fit, color="red")
plt.annotate(SouthHL_equation,(20,-50), fontsize=12, color ="red")
plt.scatter(South_humidity, South_lat)
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere: City Humidity vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure8.png")
plt.show()
# Out:
# 0     -18.477583
# 3     -22.082416
# 6     -19.460720
# 8     -23.284027
# 9     -22.410128
#          ...
# 559   -20.225381
# 563   -17.712922
# 564   -22.082416
# 570   -19.569957
# 572   -23.939451
# Name: Humidity, Length: 175, dtype: float64
# y=0.11x + (-28.09)
#  Correlation =  0.16

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between humidity and latitude of cities in the Southern hemisphere is used to predict the latitudes of the cities given their humidity.
# * There is a weak positive relationship between humidity and latitude. That is, an increase in the humidity causes a slight increase in the latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Retrieve the cloudiness and Latitude for northern hemisphere
North_city_data.head()
North_cloud = North_city_data.iloc[:,8]
North_lat = North_city_data.iloc[:,6]

# Perform linear regression of cloudiness vs. Latitude
NCL_slope, NCL_int, NCL_r, NCL_p, NCL_std_err = linregress(North_cloud, North_lat)
NCL_fit = NCL_slope * North_cloud + NCL_int
print(NCL_fit)

# Print the regression equation
NorthCL_equation =  f"y={round(NCL_slope, 2)}x + {round(NCL_int,2)}"
print(NorthCL_equation)

# Compute and print the correlation 
print(f" Correlation = {round((NCL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(North_cloud, NCL_fit, color="red")
plt.annotate(NorthCL_equation,(20,70), fontsize=12, color ="red")
plt.scatter(North_cloud, North_lat)
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere: City Cloudiness vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure9.png")
plt.show()
# Out:
# 1      41.102812
# 2      41.102812
# 4      43.478269
# 5      38.727355
# 7      42.722442
#          ...
# 566    33.004664
# 567    33.004664
# 568    33.004664
# 569    43.694220
# 571    42.722442
# Name: Cloudiness, Length: 398, dtype: float64
# y=0.11x + 33.0
#  Correlation = 0.22

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between cloudiness and latitude of cities in the northern hemisphere is used to predict the latitudes of the cities given their cloudiness.
# * There is a weak positive relationship between cloudiness and latitude. That is, an increase in the cloudiness causes a slight increase in the latitude.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Retrieve the cloudiness and Latitude for northern hemisphere
South_city_data.head()
South_cloud = South_city_data.iloc[:,8]
South_lat = South_city_data.iloc[:,6]

# Perform linear regression of cloudiness vs. Latitude
SCL_slope, SCL_int, SCL_r, SCL_p, SCL_std_err = linregress(South_cloud, South_lat)
SCL_fit = SCL_slope * South_cloud + SCL_int
print(SCL_fit)

# Print the regression equation
SouthCL_equation =  f"y={round(SCL_slope, 2)}x + ({round(SCL_int,2)})"
print(SouthCL_equation)

# Compute and print the correlation
print(f" Correlation = {round((SCL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.annotate(SouthCL_equation,(10,-50), fontsize=12, color ="red")
plt.plot(South_cloud, SCL_fit, color="red")
plt.scatter(South_cloud, South_lat)
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere: City Cloudiness vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure10.png")
plt.show()
# Out:
# 0     -17.022094
# 3     -25.739393
# 6     -14.232558
# 8     -23.414780
# 9     -25.739393
#          ...
# 559   -22.601166
# 563   -14.116327
# 564   -25.042009
# 570   -23.414780
# 572   -15.162403
# Name: Cloudiness, Length: 175, dtype: float64
# y=0.12x + (-25.74)
#  Correlation = 0.34

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between cloudiness and latitude of cities in the southern hemisphere is used to predict the latitudes of the cities given their cloudiness.
# * There is a weak positive relationship between cloudiness and latitude. That is, an increase in the cloudiness causes a slight increase in the latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Retrieve the wind speed and Latitude for northern hemisphere
North_city_data.head()
North_windspeed = North_city_data.iloc[:,7]
North_lat = North_city_data.iloc[:,6]

# Perform linear regression of wind speed vs. Latitude
NWL_slope, NWL_int, NWL_r, NWL_p, NWL_std_err = linregress(North_windspeed, North_lat)
NWL_fit = NWL_slope * North_windspeed + NWL_int
print(NWL_fit)

# Print the regression equation
NorthWL_equation =  f"y={round(NWL_slope, 2)}x + {round(NWL_int,2)}"
print(NorthWL_equation)

# Compute and print the correlation 
print(f" Correlation = {round((NWL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(North_windspeed, NWL_fit, color="red")
plt.annotate(NorthWL_equation,(10,10), fontsize=12, color ="red")
plt.scatter(North_windspeed, North_lat)
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere: City Wind Speed vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure11.png")
plt.show()
# Out:
# 1      36.880151
# 2      35.151507
# 4      33.831452
# 5      35.764390
# 7      48.980656
#          ...
# 566    38.263066
# 567    36.880151
# 568    36.062974
# 569    41.343194
# 571    33.580013
# Name: WindSpeed, Length: 398, dtype: float64
# y=1.57x + 32.79
#  Correlation = 0.2

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between the wind speed and latitude of cities in the northern hemisphere is used to predict the latitudes of the cities given their wind speed.
# * There is a weak positive relationship between wind speed and latitude. That is, an increase in the wind speed causes a slight increase in the latitude.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Retrieve the wind speed and Latitude for southern hemisphere
South_city_data.head()
South_windspeed = South_city_data.iloc[:,7]
South_lat = South_city_data.iloc[:,6]

# Perform linear regression of wind speed vs. Latitude
SWL_slope, SWL_int, SWL_r, SWL_p, SWL_std_err = linregress(South_windspeed, South_lat)
SWL_fit = SWL_slope * South_windspeed + SWL_int
print(SWL_fit)

# Print the regression equation
SouthWL_equation =  f"y={round(SWL_slope, 2)}x + ({round(SWL_int,2)})"
print(SouthWL_equation)

# Compute and print the correlation 
print(f" Correlation = {round((SWL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(South_windspeed, SWL_fit, color="red")
plt.annotate(SouthWL_equation,(2,-50), fontsize=12, color ="red")
plt.scatter(South_windspeed, South_lat)
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere: City Wind Speed vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure12.png")
plt.show()
# Out:
# 0     -16.836312
# 3     -18.725035
# 6     -21.497843
# 8     -26.721973
# 9     -23.145453
#          ...
# 559   -26.159374
# 563   -14.646196
# 564   -14.947588
# 570   -21.497843
# 572   -25.074363
# Name: WindSpeed, Length: 175, dtype: float64
# y=-2.01x + (-13.26)
#  Correlation = -0.38

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between the wind speed and latitude of cities in the southern hemisphere is used to predict the latitudes of the cities given their wind speed.
# * There is a weak negative relationship between wind speed and latitude. That is, an increase in the wind speed causes a slight decrease in the latitude.
