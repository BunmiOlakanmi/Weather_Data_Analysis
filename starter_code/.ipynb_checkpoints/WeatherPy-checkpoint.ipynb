# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ## Observations and Insights
#
# ### Analysis
#
# * On the overall, most cities analysed are from the northern hemisphere. That is, 382 of the 580 random cities selected when the code was last executed.
# *  With respects to the scatter plots, there is a negative non-linear correlation observed in the relationship between city's latitude and temperature, while there is a positive correlation between the city's latitude and humidity. However, there is no correlation observed in the relationships between city's latitude and cloudiness, and between city's latitude and the wind speed.
# *  With respect to linear regression, cities in both northern and southern hemispheres have strong correlation between max temperature and latitude, although the cities in the northern hemisphere have an inverse correlation. This is understandable because generally around the world, it gets warmer towards the equator and cooler towards the poles.

# %%
# Import all dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json 
from scipy.stats import linregress
import datetime as dt 
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Generate Cities List

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))

# Print Cities List
print(cities)
# Out:
# 596
# ['atar', 'albany', 'rungata', 'tadine', 'ugoofaaru', 'luderitz', 'jamestown', 'nikolskoye', 'cabra', 'kaitangata', 'lata', 'sabang', 'yellowknife', 'torbay', 'batagay-alyta', 'kalabagh', 'chagda', 'bluff', 'tuktoyaktuk', 'nizhniy kuranakh', 'barrow', 'moree', 'east london', 'buarcos', 'tumannyy', 'port alfred', 'bethel', 'qaanaaq', 'severo-kurilsk', 'rikitea', 'kadhan', 'ushuaia', 'ngunguru', 'bredasdorp', 'mansoa', 'upernavik', 'mataura', 'mahebourg', 'hilo', 'taoudenni', 'airai', 'cape town', 'hermanus', 'erenhot', 'kindu', 'atuona', 'saint george', 'mitsamiouli', 'hofn', 'pevek', 'yar-sale', 'new norfolk', 'hihifo', 'kokomo', 'cockburn town', 'alexandria', 'marsaxlokk', 'bathsheba', 'punta arenas', 'barentsburg', 'sao domingos', 'avarua', 'ciudad ojeda', 'georgetown', 'mosonmagyarovar', 'kapaa', 'dunedin', 'fayaoue', 'kiknur', 'hobart', 'rayon', 'taolanaro', 'baykalsk', 'nome', 'lebedyn', 'butaritari', 'los llanos de aridane', 'iqaluit', 'jumla', 'inyonga', 'mar del plata', 'hithadhoo', 'hami', 'namibe', 'aksarka', 'karabulak', 'rizhao', 'toplita', 'belushya guba', 'dikson', 'kahului', 'busselton', 'shenjiamen', 'luanda', 'atherton', 'tsihombe', 'polis', 'deming', 'hasaki', 'bintulu', 'vila franca do campo', 'coahuayana', 'mayumba', 'kavaratti', 'yamasaki', 'turukhansk', 'egvekinot', 'port elizabeth', 'tuatapere', 'broome', 'alofi', 'pacific grove', 'flagstaff', 'jalu', 'de aar', 'wahiawa', 'attawapiskat', 'norman wells', 'goderich', 'saint-francois', 'thompson', 'boysun', 'lebu', 'cayenne', 'chokurdakh', 'kalabo', 'caetite', 'illoqqortoormiut', 'leningradskiy', 'peterhead', 'elizabeth city', 'port shepstone', 'viligili', 'madona', 'arraial do cabo', 'castro', 'prestea', 'meridian', 'khatanga', 'hamilton', 'walvis bay', 'valdivia', 'kurud', 'portland', 'kodiak', 'vaini', 'ust-nera', 'port hardy', 'pangkalanbuun', 'rocha', 'jacareacanga', 'mbanza-ngungu', 'huarmey', 'lima', 'lompoc', 'fairbanks', 'visnes', 'swan hill', 'sobolevo', 'half moon bay', 'ust-omchug', 'port macquarie', 'rawson', 'banff', 'sioux lookout', 'kenai', 'biscarrosse', 'saint-philippe', 'matagami', 'coquimbo', 'lakes entrance', 'acapulco', 'aflu', 'cabo san lucas', 'nyurba', 'mahibadhoo', 'carnarvon', 'virginia beach', 'codrington', 'puerto ayora', 'pundaguitan', 'manaure', 'port blair', 'yulara', 'tasiilaq', 'fonte boa', 'carutapera', 'ancud', 'vaitupu', 'lasem', 'ayia', 'ribeira grande', 'cherskiy', 'nanortalik', 'kongolo', 'socorro', 'tarakan', 'mandurah', 'sola', 'umzimvubu', 'northam', 'sur', 'flinders', 'linjiang', 'saint simons', 'grand river south east', 'hirara', 'tsienyane', 'sentyabrskiy', 'victoria', 'amderma', 'ugra', 'tupik', 'sitka', 'jawhar', 'klaksvik', 'ponta do sol', 'klyavlino', 'okato', 'ostrovnoy', 'grand gaube', 'binzhou', 'ulaangom', 'ixtapa', 'zhicheng', 'mys shmidta', 'quatre cocos', 'bengkulu', 'kegayli', 'kidal', 'phalodi', 'rabo de peixe', 'dubasari', 'zhigansk', 'achutupo', 'adrar', 'ruatoria', 'havre-saint-pierre', 'birao', 'mianyang', 'vila do maio', 'honningsvag', 'kandiari', 'chuy', 'okhotsk', 'haademeeste', 'san quintin', 'grindavik', 'saint-andre-les-vergers', 'emerald', 'polyanka', 'samusu', 'lorengau', 'auki', 'lavrentiya', 'artyk', 'san roque', 'pangnirtung', 'kruisfontein', 'najran', 'saryg-sep', 'bilma', 'qasigiannguit', 'saskylakh', 'dapaong', 'tevriz', 'constitucion', 'shibetsu', 'katsuura', 'angoram', 'dingle', 'sistranda', 'balkanabat', 'diego de almagro', 'santa isabel', 'ketchikan', 'mandera', 'harper', 'umm lajj', 'ponta delgada', 'dong xoai', 'marshall', 'vardo', 'la asuncion', 'beohari', 'saldanha', 'olinda', 'guaratinga', 'deer lake', 'faanui', 'umm durman', 'saleaula', 'saint-augustin', 'eydhafushi', 'port lincoln', 'provideniya', 'padang', 'luganville', 'greenfield', 'taltal', 'kloulklubed', 'kabo', 'kaeo', 'tiksi', 'kamaishi', 'stromness', 'bonito', 'fortuna', 'catia la mar', 'inhambane', 'allada', 'nizhneyansk', 'moerai', 'narsaq', 'monte patria', 'valleyview', 'erzin', 'smirnykh', 'whitecourt', 'uruca ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Components of API 
city_data = []
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Initializze a counter to store the city number
counter = 1

# Perform a weather check 
# on each of the cities using a series of successive API calls
# Then, extract the weather components (latitude, temperature, wind speed..)
# needed for our analyses and chats
for city in cities:
    try:
        query_url = f"{url}&appid={weather_api_key}&units={units}&q={city}"
        weather_response = requests.get(query_url).json()
        city_humidity = weather_response["main"]["humidity"]
        city_temp = weather_response["main"]["temp"]
        city_Maxtemp = weather_response["main"]["temp_max"]
        city_lat = weather_response["coord"]["lat"] 
        city_wind = weather_response["wind"]["speed"]
        city_cloud = weather_response["clouds"]["all"]
        city_country = weather_response["sys"]["country"]
        city_datetime = weather_response["dt"]
        city_lon = weather_response["coord"]["lon"]
        # Print a log of each city with the city number and city name
        print(f"processing record number {counter} | {city}")
        counter += 1
        city_data.append ({"City":city,
                           "Country": city_country,
                           "DateTime":city_datetime,
                           "Humidity": city_humidity,
                           "Temperature": city_temp,
                           "Max. Temp.":  city_Maxtemp,
                           "Latitude": city_lat,
                           "WindSpeed": city_wind,
                           "Cloudiness": city_cloud,
                           "Longitude": city_lon
                     })        
    except:
        # Print city does not exist, if the city details are missing
        print("City does not exist")
        pass
# Out:
# processing record number 1 | albany
# processing record number 2 | lipin bor
# processing record number 3 | hilo
# processing record number 4 | marsh harbour
# City does not exist
# City does not exist
# City does not exist
# processing record number 5 | salalah
# processing record number 6 | jining
# processing record number 7 | vaini
# processing record number 8 | bredasdorp
# processing record number 9 | rio grande
# processing record number 10 | rikitea
# processing record number 11 | alice town
# processing record number 12 | provideniya
# processing record number 13 | parrita
# processing record number 14 | yeppoon
# processing record number 15 | angoche
# processing record number 16 | playas
# processing record number 17 | hamilton
# processing record number 18 | butaritari
# processing record number 19 | broome
# processing record number 20 | ushuaia
# processing record number 21 | lebu
# processing record number 22 | bambanglipuro
# processing record number 23 | chuy
# processing record number 24 | gorontalo
# processing record number 25 | muros
# processing record number 26 | padang
# City does not exist
# processing record number 27 | port elizabeth
# processing record number 28 | saldanha
# processing record number 29 | karratha
# processing record number 30 | devils lake
# processing record number 31 | punta arenas
# processing record number 32 | homa bay
# processing record number 33 | nyurba
# processing record number 34 | kapaa
# processing record number 35 | deloraine
# City does not exist
# processing record number 36 | cape town
# processing record number 37 | esperance
# processing record number 38 | hermanus
# City does not exist
# processing record number 39 | siteki
# processing record number 40 | asau
# City does not exist
# processing record number 41 | gamba
# processing record number 42 | sandusky
# processing record number 43 | san juan
# processing record number 44 | khatanga
# processing record number 45 | lovington
# processing record number 46 | port-gentil
# City does not exist
# processing record number 47 | mahebourg
# processing record number 48 | kawalu
# processing record number 49 | chipata
# processing record number 50 | atuona
# processing record number 51 | mazagao
# processing record number 52 | olafsvik
# processing record number 53 | gornopravdinsk
# processing record number 54 | jackson
# processing record number 55 | talnakh
# processing record number 56 | juneau
# City does not exist
# processing record number 57 | narsaq
# processing record number 58 | tuktoyaktuk
# processing record number 59 | aklavik
# processing record number 60 | bataipora
# processing record number 61 | alta floresta
# processing record number 62 | port alfred
# processing record number 63 | isangel
# processing record number 64 | castro
# processing record number 65 | carnarvon
# processing record number 66 | akhmim
# processing record number 67 | hit
# processing record number 68 | svetlyy
# processing record number 69 | kjollefjord
# processing record number 70 | meulaboh
# processing record number 71 | ilulissat
# processing record number 72 | arraial do cabo
# processing record number 73 | calama
# processing record number 74 | cidreira
# processing record number 75 | barrow
# processing record number 76 | pevek
# processing record number 77 | ivankiv
# City does not exist
# City does not exist
# processing record number 78 | savannah bight
# processing record number 79 | puerto ayora
# processing record number 80 | lata
# processing record number 81 | bluff
# processing record number 82 | gouyave
# processing record number 83 | sechura
# processing record number 84 | rio gallegos
# City does not exist
# processing record number 85 | merauke
# processing record number 86 | esna
# processing record number 87 | ust-tsilma
# processing record number 88 | qaanaaq
# City does not exist
# processing record number 89 | pingdu
# processing record number 90 | vanimo
# processing record number 91 | cherskiy
# processing record number 92 | kapit
# processing record number 93 | college
# processing record number 94 | tomatlan
# processing record number 95 | sao joao da barra
# processing record number 96 | yellowknife
# processing record number 97 | sao filipe
# processing record number 98 | mount isa
# processing record number 99 | hasaki
# processing record number 100 | ahipara
# processing record number 101 | vao
# processing record number 102 | mataura
# processing record number 103 | tiksi
# processing record number 104 | awbari
# processing record number 105 | marietta
# processing record number 106 | victoria
# processing record number 107 | sabha
# processing record number 108 | lagoa
# processing record number 109 | krasnoselkup
# processing record number 110 | chapais
# processing record number 111 | upernavik
# processing record number 112 | new norfolk
# processing record number 113 | opoczno
# processing record number 114 | petatlan
# processing record number 115 | avarua
# processing record number 116 | bongandanga
# processing record number 117 | nanortalik
# processing record number 118 | airai
# processing record number 119 | matara
# processing record number 120 | bethel
# processing record number 121 | vila velha
# processing record number 122 | krasnoarmeyskoye
# processing record number 123 | petropavlovsk-kamchatskiy
# processing record number 124 | nikolskoye
# processing record number 125 | los llanos de aridane
# processing record number 126 | arapongas
# processing record number 127 | altay
# processing record number 128 | laredo
# processing record number 129 | korla
# processing record number 130 | gorom-gorom
# processing record number 131 | kaitangata
# processing record number 132 | coihaique
# processing record number 133 | mitsamiouli
# processing record number 134 | san patricio
# processing record number 135 | tazovskiy
# processing record number 136 | lasa
# processing record number 137 | thompson
# processing record number 138 | sembe
# processing record number 139 | severo-kurilsk
# processing record number 140 | port lincoln
# processing record number 141 | half moon bay
# processing record number 142 | grindavik
# processing record number 143 | lavrentiya
# processing record number 144 | mokrousovo
# processing record number 145 | napier
# processing record number 146 | dehui
# processing record number 147 | pozo colorado
# processing record number 148 | bodaybo
# processing record number 149 | le moule
# processing record number 150 | alamosa
# processing record number 151 | antofagasta
# processing record number 152 | torrevieja
# processing record number 153 | mahibadhoo
# processing record number 154 | humberto de campos
# processing record number 155 | sabang
# processing record number 156 | iwanai
# processing record number 157 | touros
# processing record number 158 | gat
# processing record number 159 | busselton
# processing record number 160 | nizhniy odes
# processing record number 161 | ankazobe
# processing record number 162 | sioux lookout
# processing record number 163 | opuwo
# City does not exist
# processing record number 164 | port hardy
# processing record number 165 | souillac
# processing record number 166 | talara
# processing record number 167 | chernyshevskiy
# processing record number 168 | paita
# processing record number 169 | sobolevo
# processing record number 170 | maumere
# processing record number 171 | zhigansk
# processing record number 172 | limenaria
# processing record number 173 | grand gaube
# processing record number 174 | bathsheba
# City does not exist
# processing record number 175 | anqing
# processing record number 176 | buenos aires
# processing record number 177 | mackenzie
# processing record number 178 | kisangani
# processing record number 179 | lakes entrance
# processing record number 180 | aktash
# processing record number 181 | yangjiang
# processing record number 182 | cayenne
# processing record number 183 | ambulu
# processing record number 184 | tatarbunary
# processing record number 185 | labuhan
# processing record number 186 | puerto leguizamo
# processing record number 187 | hofn
# City does not exist
# processing record number 188 | brae
# processing record number 189 | kodiak
# processing record number 190 | kruisfontein
# processing record number 191 | guanare
# processing record number 192 | san ignacio
# processing record number 193 | longyearbyen
# processing record number 194 | rawson
# processing record number 195 | talcahuano
# processing record number 196 | dunedin
# processing record number 197 | norman wells
# processing record number 198 | itarema
# processing record number 199 | rossland
# processing record number 200 | new iberia
# processing record number 201 | soledade
# processing record number 202 | ancud
# processing record number 203 | alihe
# processing record number 204 | klaksvik
# processing record number 205 | hualmay
# processing record number 206 | meadow lake
# processing record number 207 | vila franca do campo
# processing record number 208 | brainerd
# processing record number 209 | marawi
# processing record number 210 | ribeira grande
# City does not exist
# processing record number 211 | camana
# processing record number 212 | san cristobal
# processing record number 213 | chokurdakh
# processing record number 214 | jamestown
# processing record number 215 | maceio
# processing record number 216 | haimen
# processing record number 217 | east london
# processing record number 218 | williston
# processing record number 219 | chikwawa
# processing record number 220 | tanout
# processing record number 221 | mecca
# processing record number 222 | srednekolymsk
# processing record number 223 | tahta
# processing record number 224 | nabire
# processing record number 225 | ballina
# processing record number 226 | udachnyy
# processing record number 227 | paragominas
# processing record number 228 | naze
# City does not exist
# processing record number 229 | saskylakh
# processing record number 230 | dikson
# processing record number 231 | ravar
# processing record number 232 | bengkulu
# City does not exist
# processing record number 233 | tezu
# processing record number 234 | hobart
# processing record number 235 | kamenka
# processing record number 236 | zhangye
# processing record number 237 | fortuna
# processing record number 238 | clyde river
# processing record number 239 | geraldton
# processing record number 240 | sola
# processing record number 241 | sawakin
# processing record number 242 | sorland
# processing record number 243 | guaruja
# processing record number 244 | chara
# processing record number 245 | klamath falls
# City does not exist
# City does not exist
# processing record number 246 | villefranche-de-rouergue
# processing record number 247 | dindori
# processing record number 248 | alamos
# processing record number 249 | lingsugur
# processing record number 250 | honiara
# processing record number 251 | dingle
# City does not exist
# processing record number 252 | bhadrachalam
# City does not exist
# processing record number 253 | acapulco
# processing record number 254 | lorengau
# City does not exist
# processing record number 255 | paka
# processing record number 256 | gbadolite
# processing record number 257 | san carlos de bariloche
# processing record number 258 | cabo san lucas
# processing record number 259 | coari
# City does not exist
# processing record number 260 | mattru
# processing record number 261 | goroka
# processing record number 262 | bambous virieux
# processing record number 263 | asekeyevo
# processing record number 264 | yumen
# processing record number 265 | caravelas
# processing record number 266 | buldana
# processing record number 267 | lompoc
# processing record number 268 | namatanai
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# processing record number 269 | vardo
# processing record number 270 | hambantota
# processing record number 271 | faanui
# processing record number 272 | chebsara
# processing record number 273 | shache
# processing record number 274 | atambua
# processing record number 275 | ulladulla
# processing record number 276 | charters towers
# processing record number 277 | bad hofgastein
# processing record number 278 | tasiilaq
# processing record number 279 | bhabua
# City does not exist
# processing record number 280 | barreiras
# processing record number 281 | port hedland
# processing record number 282 | ilo
# processing record number 283 | tura
# City does not exist
# processing record number 284 | naryan-mar
# processing record number 285 | cocorit
# processing record number 286 | solnechnyy
# processing record number 287 | vostok
# processing record number 288 | flin flon
# processing record number 289 | itai
# processing record number 290 | port blair
# processing record number 291 | salinas
# processing record number 292 | hithadhoo
# processing record number 293 | gejiu
# processing record number 294 | araxa
# processing record number 295 | celestun
# processing record number 296 | sao felix do xingu
# processing record number 297 | broadford
# processing record number 298 | hay river
# processing record number 299 | mar del plata
# processing record number 300 | ponta do sol
# processing record number 301 | lima
# processing record number 302 | rudnaya pristan
# City does not exist
# processing record number 303 | sorgun
# processing record number 304 | kavieng
# processing record number 305 | sharan
# processing record number 306 | fort nelson
# processing record number 307 | itupiranga
# processing record number 308 | husavik
# processing record number 309 | banda aceh
# processing record number 310 | abu samrah
# processing record number 311 | alofi
# processing record number 312 | tabou
# processing record number 313 | belomorsk
# processing record number 314 | ust-nera
# processing record number 315 | miri
# processing record number 316 | kurchum
# processing record number 317 | nuuk
# processing record number 318 | porosozero
# processing record number 319 | turochak
# processing record number 320 | mishan
# processing record number 321 | mount gambier
# processing record number 322 | trinidad
# processing record number 323 | saint-philippe
# processing record number 324 | daru
# processing record number 325 | adrar
# processing record number 326 | shimoda
# processing record number 327 | atocha
# processing record number 328 | mehamn
# processing record number 329 | jumla
# City does not exist
# processing record number 330 | manzanillo
# processing record number 331 | pisco
# processing record number 332 | pitimbu
# processing record number 333 | ostersund
# processing record number 334 | coahuayana
# City does not exist
# City does not exist
# processing record number 335 | visby
# processing record number 336 | ust-kan
# processing record number 337 | primo tapia
# processing record number 338 | channel-port aux basques
# City does not exist
# processing record number 339 | zabaykalsk
# City does not exist
# processing record number 340 | nome
# processing record number 341 | xianyang
# processing record number 342 | sitka
# processing record number 343 | nantucket
# processing record number 344 | constitucion
# processing record number 345 | deputatskiy
# processing record number 346 | aksarka
# processing record number 347 | tuatapere
# processing record number 348 | mercedes
# processing record number 349 | marshall
# processing record number 350 | inuvik
# processing record number 351 | roebourne
# processing record number 352 | luwuk
# processing record number 353 | harper
# processing record number 354 | cozumel
# processing record number 355 | amli
# processing record number 356 | pokhara
# processing record number 357 | te anau
# processing record number 358 | belaya gora
# processing record number 359 | ambalavao
# processing record number 360 | eyl
# processing record number 361 | kiruna
# processing record number 362 | bilma
# processing record number 363 | puerto madryn
# processing record number 364 | pakxan
# processing record number 365 | pangkalanbuun
# processing record number 366 | amapa
# processing record number 367 | viedma
# processing record number 368 | goya
# processing record number 369 | sinnamary
# processing record number 370 | yen bai
# processing record number 371 | la ronge
# processing record number 372 | ostrovnoy
# processing record number 373 | sayyan
# processing record number 374 | belvedere marittimo
# processing record number 375 | kahului
# processing record number 376 | coquimbo
# processing record number 377 | aykhal
# processing record number 378 | livingstone
# processing record number 379 | troitskaya
# processing record number 380 | monrovia
# processing record number 381 | wildeshausen
# processing record number 382 | georgetown
# processing record number 383 | kodinsk
# processing record number 384 | bud
# processing record number 385 | bako
# processing record number 386 | kikwit
# processing record number 387 | carmen
# processing record number 388 | trairi
# processing record number 389 | marrakesh
# processing record number 390 | beloha
# City does not exist
# processing record number 391 | russell
# processing record number 392 | gerede
# processing record number 393 | teguise
# processing record number 394 | abha
# processing record number 395 | namibe
# processing record number 396 | walvis bay
# processing record number 397 | kirakira
# processing record number 398 | saint-joseph
# processing record number 399 | palana
# processing record number 400 | shahrud
# processing record number 401 | linqiong
# processing record number 402 | sangar
# processing record number 403 | grootfontein
# processing record number 404 | dakar
# processing record number 405 | diffa
# processing record number 406 | pangoa
# processing record number 407 | bor
# processing record number 408 | curvelo
# processing record number 409 | emba
# processing record number 410 | dosso
# processing record number 411 | chalmette
# processing record number 412 | smithers
# processing record number 413 | griffith
# City does not exist
# processing record number 414 | sambava
# processing record number 415 | belyy yar
# processing record number 416 | kysyl-syr
# processing record number 417 | snihurivka
# processing record number 418 | saint george
# processing record number 419 | pontal do parana
# processing record number 420 | bayonet point
# processing record number 421 | niamey
# processing record number 422 | francistown
# processing record number 423 | herat
# processing record number 424 | salinopolis
# processing record number 425 | iqaluit
# processing record number 426 | vytegra
# processing record number 427 | pierre
# processing record number 428 | gunzburg
# processing record number 429 | guerrero negro
# processing record number 430 | pelym
# processing record number 431 | imamoglu
# processing record number 432 | katsuura
# processing record number 433 | kuryk
# processing record number 434 | sibolga
# processing record number 435 | chipinge
# processing record number 436 | praia da vitoria
# processing record number 437 | mayo
# processing record number 438 | abbeville
# processing record number 439 | greenfield
# processing record number 440 | wanaka
# processing record number 441 | goderich
# processing record number 442 | ola
# processing record number 443 | bella union
# processing record number 444 | moose factory
# processing record number 445 | bathurst
# processing record number 446 | tigil
# processing record number 447 | sao caetano de odivelas
# processing record number 448 | port arthur
# processing record number 449 | yaan
# processing record number 450 | pouembout
# processing record number 451 | port macquarie
# processing record number 452 | xichang
# processing record number 453 | buhe
# processing record number 454 | inta
# processing record number 455 | chokwe
# processing record number 456 | alikalia
# processing record number 457 | morganton
# processing record number 458 | thai binh
# processing record number 459 | aransas pass
# City does not exist
# processing record number 460 | baillif
# processing record number 461 | lyuban
# processing record number 462 | andilamena
# processing record number 463 | lumeje
# processing record number 464 | bacolod
# processing record number 465 | waipawa
# City does not exist
# processing record number 466 | albania
# processing record number 467 | valdivia
# City does not exist
# processing record number 468 | port keats
# processing record number 469 | saint-georges
# processing record number 470 | kidal
# processing record number 471 | wonthaggi
# processing record number 472 | barabash
# City does not exist
# processing record number 473 | noumea
# processing record number 474 | mabaruma
# processing record number 475 | kostrzyn
# processing record number 476 | hanchuan
# processing record number 477 | newport
# processing record number 478 | cabedelo
# processing record number 479 | rudnogorsk
# City does not exist
# processing record number 480 | rongcheng
# processing record number 481 | puerto ayacucho
# processing record number 482 | luderitz
# processing record number 483 | noyabrsk
# processing record number 484 | bar harbor
# processing record number 485 | edgewater
# processing record number 486 | zlobin
# processing record number 487 | gannan
# processing record number 488 | cockburn town
# City does not exist
# processing record number 489 | monster
# processing record number 490 | lang suan
# processing record number 491 | arlit
# processing record number 492 | vestmanna
# processing record number 493 | luorong
# processing record number 494 | dalvik
# processing record number 495 | nouadhibou
# processing record number 496 | kesan
# processing record number 497 | san jeronimito
# processing record number 498 | zaysan
# processing record number 499 | nawabganj
# processing record number 500 | yuksekova
# City does not exist
# processing record number 501 | murray bridge
# processing record number 502 | birao
# processing record number 503 | odweyne
# processing record number 504 | atar
# processing record number 505 | esperanza
# processing record number 506 | neuenhof
# processing record number 507 | vallenar
# processing record number 508 | codrington
# processing record number 509 | dzilam gonzalez
# processing record number 510 | tessalit
# processing record number 511 | quatre cocos
# processing record number 512 | cururupu
# processing record number 513 | darapidap
# processing record number 514 | tres arroyos
# processing record number 515 | la palma
# processing record number 516 | diu
# processing record number 517 | mayor pablo lagerenza
# processing record number 518 | rovaniemi
# processing record number 519 | ilovlya
# processing record number 520 | liberia
# processing record number 521 | leningradskiy
# processing record number 522 | warmbad
# processing record number 523 | malmyzh
# processing record number 524 | hirara
# processing record number 525 | kavaratti
# processing record number 526 | bandarbeyla
# processing record number 527 | burhanpur
# processing record number 528 | lago da pedra
# processing record number 529 | otjiwarongo
# processing record number 530 | manuk mangkaw
# processing record number 531 | nairobi
# processing record number 532 | romitan
# City does not exist
# processing record number 533 | viesca
# processing record number 534 | yulara
# processing record number 535 | kindersley
# City does not exist
# City does not exist
# processing record number 536 | ust-maya
# processing record number 537 | sand
# processing record number 538 | genoa
# processing record number 539 | billings
# processing record number 540 | araouane
# processing record number 541 | maniitsoq
# processing record number 542 | alice springs
# processing record number 543 | simbahan
# processing record number 544 | callaguip
# processing record number 545 | mountain home
# City does not exist
# processing record number 546 | mananjary
# processing record number 547 | kendari
# processing record number 548 | ngunguru
# processing record number 549 | torbay
# processing record number 550 | serenje
# City does not exist
# City does not exist
# processing record number 551 | ampanihy
# processing record number 552 | skjervoy
# processing record number 553 | belmonte
# City does not exist
# processing record number 554 | dandong
# processing record number 555 | santa vitoria do palmar
# processing record number 556 | buala
# processing record number 557 | sahuaripa
# processing record number 558 | bafra
# processing record number 559 | otane
# City does not exist
# City does not exist
# processing record number 560 | osakarovka
# City does not exist
# processing record number 561 | genhe
# processing record number 562 | pingliang
# processing record number 563 | basoko
# City does not exist
# processing record number 564 | prince rupert
# processing record number 565 | lumby
# processing record number 566 | venice
# processing record number 567 | marshfield
# processing record number 568 | ulaangom
# processing record number 569 | oranjemund
# City does not exist
# processing record number 570 | dezful
# processing record number 571 | mount abu
# processing record number 572 | bom jardim
# processing record number 573 | severo-yeniseyskiy
# processing record number 574 | aswan
# processing record number 575 | bosaso
# processing record number 576 | gambela
# processing record number 577 | comodoro rivadavia
# processing record number 578 | fontem
# processing record number 579 | puyang
# processing record number 580 | nenjiang

# %%
weather_response
# Out:
# {'coord': {'lon': 125.22, 'lat': 49.18},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': -5.36,
#   'feels_like': -12.71,
#   'temp_min': -5.36,
#   'temp_max': -5.36,
#   'pressure': 1013,
#   'humidity': 94,
#   'sea_level': 1013,
#   'grnd_level': 985},
#  'visibility': 10000,
#  'wind': {'speed': 6.6, 'deg': 341},
#  'clouds': {'all': 100},
#  'dt': 1604780893,
#  'sys': {'country': 'CN', 'sunrise': 1604788681, 'sunset': 1604822866},
#  'timezone': 28800,
#  'id': 2035601,
#  'name': 'Mergen',
#  'cod': 200}

# %%
# Convert city_data to DataFrame
city_data = pd.DataFrame(city_data)
city_data

# Export the city data into a .csv 
city_data.to_csv(output_data_file, encoding="utf-8", index=False)
city_data
# Out:
#                    City Country    DateTime  Humidity  Temperature  \
# 0                albany      US  1604780661        43        20.59
# 1             lipin bor      RU  1604780767        84         6.78
# 2                  hilo      US  1604780745        78        24.36
# 3         marsh harbour      BS  1604780485        75        26.31
# 4               salalah      OM  1604780550        69        24.00
# ..                  ...     ...         ...       ...          ...
# 575             gambela      ET  1604780892        81        23.69
# 576  comodoro rivadavia      AR  1604780679        48        19.00
# 577              fontem      CM  1604780892        92        19.85
# 578              puyang      CN  1604780892        17        16.67
# 579            nenjiang      CN  1604780893        94        -5.36
#
#      Max. Temp.  Latitude  WindSpeed  Cloudiness  Longitude
# 0         21.11     42.60       2.60          75     -73.97
# 1          6.78     60.26       7.39          97      37.98
# 2         26.67     19.73       4.10          90    -155.09
# 3         26.31     26.54      11.99         100     -77.06
# 4         24.00     17.02       1.00           0      54.09
# ..          ...       ...        ...         ...        ...
# 575       23.69      8.25       1.20          75      34.58
# 576       19.00    -45.87       6.70           0     -67.50
# 577       19.85      5.47       0.78         100       9.88
# 578       16.67     29.46       1.04           4     119.89
# 579       -5.36     49.18       6.60         100     125.22
#
# [580 rows x 10 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
len(city_data)
# Out:
# 580

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Check the city_data for cities with humidity <= 100
clean_city_data = city_data.loc[(
    city_data["Humidity"] <= 100)]
clean_city_data

# The cities with humidity below or equal to 100 
# are still the same cities in our original datasets
# Out:
#                    City Country    DateTime  Humidity  Temperature  \
# 0                albany      US  1604780661        43        20.59
# 1             lipin bor      RU  1604780767        84         6.78
# 2                  hilo      US  1604780745        78        24.36
# 3         marsh harbour      BS  1604780485        75        26.31
# 4               salalah      OM  1604780550        69        24.00
# ..                  ...     ...         ...       ...          ...
# 575             gambela      ET  1604780892        81        23.69
# 576  comodoro rivadavia      AR  1604780679        48        19.00
# 577              fontem      CM  1604780892        92        19.85
# 578              puyang      CN  1604780892        17        16.67
# 579            nenjiang      CN  1604780893        94        -5.36
#
#      Max. Temp.  Latitude  WindSpeed  Cloudiness  Longitude
# 0         21.11     42.60       2.60          75     -73.97
# 1          6.78     60.26       7.39          97      37.98
# 2         26.67     19.73       4.10          90    -155.09
# 3         26.31     26.54      11.99         100     -77.06
# 4         24.00     17.02       1.00           0      54.09
# ..          ...       ...        ...         ...        ...
# 575       23.69      8.25       1.20          75      34.58
# 576       19.00    -45.87       6.70           0     -67.50
# 577       19.85      5.47       0.78         100       9.88
# 578       16.67     29.46       1.04           4     119.89
# 579       -5.36     49.18       6.60         100     125.22
#
# [580 rows x 10 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
reduced_city_data = city_data.loc[(
    city_data["Humidity"] > 100)]
reduced_city_data.index

# There is no city with humidity>100.
# So, this step and the next step are skipped
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Retrieve the latitude and temperature from city_data
latitude = city_data["Latitude"].tolist()
latitude
temperature = city_data["Temperature"].tolist()
temperature


# Plot the scatter diagram of latitude vs. temperature
plt.scatter(latitude, temperature, color = "red")

# Include the axes labels, plot title, and date of analysis
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("City Latitude vs. Temperature (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure1.png")

# %% [markdown]
# #### What the lines of code in the previous cell achieve
# * The lines of codes in this cell generate the scatter plots of latitude VS.temperature in order to show how much a city's temperature is affected by its latitude.
# * The scatter plotts show that there is a negative non-linear correlation between latitude and temperature.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Retrieve the humidity from city_data
humidity = city_data["Humidity"].tolist()
humidity

# Plot the scatter diagram of latitude vs. humidity
plt.scatter(latitude, humidity, color="yellowgreen")

# Include the axes labels, plot title, and date of analysis
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure2.png")

# %% [markdown]
# #### What the lines of code in the previous cell achieve
# * The lines of codes in this cell generate the scatter plots of latitude VS.humidity in order to show how much a city's humidity is affected by its latitude.
# * The scatter plotts show that there is a positive correlation between latitude and humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Retrieve the cloudiness from city_data
cloudiness = city_data["Cloudiness"].tolist()
cloudiness

# Plot the scatter diagram of latitude vs. cloudiness
plt.scatter(latitude, cloudiness, color="purple")

# Include the axes labels, plot title, and date of analysis
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure3.png")

# %% [markdown]
# #### What the lines of code in the previous cell achieve
# * The lines of codes in this cell generate the scatter plots of latitude VS.cloudiness in order to show how much a city's cloudiness is affected by its latitude.
# * The scatter plotts show that there is a no correlation between latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Retrieve the wind speed from city_data
windspeed = city_data["WindSpeed"].tolist()
windspeed

# Plot the scatter diagram of latitude vs. wind speed
plt.scatter(latitude, windspeed, color="brown")

# Include the axes labels, plot title, and date of analysis
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure4.png")

# %% [markdown]
# #### What the lines of code in the previous cell achieve
# * The lines of codes in this cell generate the scatter plots of latitude VS.wind speed in order to show how much a city's wind speed is affected by its latitude.
# * The scatter plots show that there is no correlation between latitude and wind speed.

# %% [markdown]
# ## Linear Regression

# %%
# Select data for Northern Hemisphere
North_city_data = city_data.loc[(
    city_data["Latitude"] >= 0)]
print(len(North_city_data))
North_city_data.head()
# Out:
# 382
#             City Country    DateTime  Humidity  Temperature  Max. Temp.  \
# 0         albany      US  1604780661        43        20.59       21.11
# 1      lipin bor      RU  1604780767        84         6.78        6.78
# 2           hilo      US  1604780745        78        24.36       26.67
# 3  marsh harbour      BS  1604780485        75        26.31       26.31
# 4        salalah      OM  1604780550        69        24.00       24.00
#
#    Latitude  WindSpeed  Cloudiness  Longitude
# 0     42.60       2.60          75     -73.97
# 1     60.26       7.39          97      37.98
# 2     19.73       4.10          90    -155.09
# 3     26.54      11.99         100     -77.06
# 4     17.02       1.00           0      54.09

# %%
# Select data for Southern Hemisphere
South_city_data = city_data.loc[(
    city_data["Latitude"] < 0)]
print(len(South_city_data))
South_city_data.head()
# Out:
# 198
#           City Country    DateTime  Humidity  Temperature  Max. Temp.  \
# 6        vaini      TO  1604780769        74        26.00       26.00
# 7   bredasdorp      ZA  1604780769        51        17.00       17.00
# 8   rio grande      BR  1604780663        73        22.00       22.00
# 9      rikitea      PF  1604780769        73        21.85       21.85
# 13     yeppoon      AU  1604780770        64        24.00       24.00
#
#     Latitude  WindSpeed  Cloudiness  Longitude
# 6     -21.20       3.10          20    -175.20
# 7     -34.53       6.70           0      20.04
# 8     -32.03       8.20          75     -52.10
# 9     -23.12       8.16          53    -134.97
# 13    -23.13       4.60          90     150.73

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Retrieve the Max Temp and Latitude for northern hemisphere
Northmax_temp = North_city_data.iloc[:,5]
North_lat = North_city_data.iloc[:,6]

# Perform linear regression of Max Temp vs. Latitude
N_slope, N_int, N_r, N_p, N_std_err = linregress(Northmax_temp, North_lat)
N_fit = N_slope * Northmax_temp + N_int
print(N_fit)

# Print the regression equation
North_equation =  f"y={round(N_slope, 2)}x + {round(N_int,2)}"
print(North_equation)

# Compute and print the correlation 
print(f" Correlation =  {round((N_r),2)}")
# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
plt.plot(Northmax_temp, N_fit, color="red")
plt.annotate(North_equation,(-20,20), fontsize=12, color ="red")
plt.scatter(Northmax_temp, North_lat)

# Include the axes labels, plot title and date of analysis
plt.ylabel("Latitude")
plt.xlabel("Max Temp")
plt.title("Northern Hemisphere City Max Temp vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure5.png")
plt.show() 
   
# After each pair of plots, explain what the linear regression is modeling
# such as any relationships you notice and any other analysis you may have.
# Out:
# 0      26.518730
# 1      44.105295
# 2      19.695191
# 3      20.137003
# 4      22.971963
#          ...
# 574    22.800147
# 575    23.352412
# 577    28.065071
# 578    31.967742
# 579    59.004171
# Name: Max. Temp., Length: 382, dtype: float64
# y=-1.23x + 52.43
#  Correlation =  -0.85

# %% [markdown]
# #### What does the linear regression model?
#
# * The linear regression between max temperature and latitude of cities in the northern hemisphere is used to predict the latitudes of the cities given their max temperature.
# * There is a strong inverse relationship between max temperature and latitude. That is, the higher the max temperature the lower the latitude.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Retrieve the Max Temp and latitude for southern hemisphere
Southmax_temp = South_city_data.iloc[:,5]
South_lat = South_city_data.iloc[:,6]

# Perform linear regression of Max Temp vs. Latitude
S_slope, S_int, S_r, S_p, S_std_err = linregress(Southmax_temp, South_lat)
S_fit = S_slope * Southmax_temp + S_int
print(S_fit)

# Print the regression equation
South_equation =  f"y={round(S_slope, 2)}x + ({round(S_int,2)})"
print(South_equation)

# Compute and print the correlation 
print(f" Correlation =  {round((S_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(Southmax_temp, S_fit, color="red")
plt.annotate(South_equation,(20,-50), fontsize=12, color ="red")
plt.scatter(Southmax_temp, South_lat)
plt.ylabel("Latitude")
plt.xlabel("Max Temp")
plt.title("Southern Hemisphere City Max Temp vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure6.png")
plt.show()
# Out:
# 6     -17.186573
# 7     -27.984098
# 8     -21.985473
# 9     -22.165432
# 13    -19.586023
#          ...
# 555   -15.746903
# 558   -24.996783
# 568   -27.528203
# 571   -14.787123
# 576   -25.584648
# Name: Max. Temp., Length: 198, dtype: float64
# y=1.2x + (-48.38)
#  Correlation =  0.59

# %% [markdown]
# #### What does the linear regression model?
#
# * The linear regression between max temperature and latitude of cities in the southern hemisphere is used to predict the latitudes of the cities given their max temperature.
# * There is a moderate positive relationship between max temperature and latitude. That is, the higher the max temperature the higher the latitude.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Retrieve the humidity for northern hemisphere
North_city_data.head()
North_humidity = North_city_data.iloc[:,3]
North_lat = North_city_data.iloc[:,6]

# Perform linear regression of humidity vs. Latitude
NHL_slope, NHL_int, NHL_r, NHL_p, NHL_std_err = linregress(North_humidity, North_lat)
NHL_fit = NHL_slope * North_humidity + NHL_int
print(NHL_fit)

# Print the regression equation
NorthHL_equation =  f"y={round(NHL_slope, 2)}x + {round(NHL_int,2)}"
print(NorthHL_equation)

# Compute and print the correlation 
print(f" Correlation =  {round((NHL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(North_humidity, NHL_fit, color="red")
plt.annotate(NorthHL_equation,(20,70), fontsize=12, color ="red")
plt.scatter(North_humidity, North_lat)
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere City Humidity vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure7.png")
plt.show()
# Out:
# 0      30.543806
# 1      41.465397
# 2      39.867116
# 3      39.067975
# 4      37.469693
#          ...
# 574    38.801594
# 575    40.666256
# 577    43.596439
# 578    23.617919
# 579    44.129200
# Name: Humidity, Length: 382, dtype: float64
# y=0.27x + 19.09
#  Correlation =  0.28

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between humidity and latitude of cities in the northern hemisphere is used to predict the latitudes of the cities given their humidity.
# * There is a weak positive relationship between humidity and latitude. That is, an increase in the humidity causes a slight increase in the latitude.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Retrieve the humidity for northern hemisphere
South_city_data.head()
South_humidity = South_city_data.iloc[:,3]
South_lat = South_city_data.iloc[:,6]

# Perform linear regression of humidity vs. Latitude
SHL_slope, SHL_int, SHL_r, SHL_p, SHL_std_err = linregress(South_humidity, South_lat)
SHL_fit = SHL_slope * South_humidity + SHL_int
print(SHL_fit)

# Print the regression equation
SouthHL_equation =  f"y={round(SHL_slope, 2)}x + ({round(SHL_int,2)})"
print(SouthHL_equation)

# Compute and print the correlation 
print(f" Correlation =  {round((SHL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(South_humidity, SHL_fit, color="red")
plt.annotate(SouthHL_equation,(20,-50), fontsize=12, color ="red")
plt.scatter(South_humidity, South_lat)
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere City Humidity vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure8.png")
plt.show()
# Out:
# 6     -20.792059
# 7     -23.327781
# 8     -20.902308
# 9     -20.902308
# 13    -21.894547
#          ...
# 555   -20.681810
# 558   -21.343303
# 568   -19.579322
# 571   -22.225293
# 576   -23.658528
# Name: Humidity, Length: 198, dtype: float64
# y=0.11x + (-28.95)
#  Correlation =  0.17

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between humidity and latitude of cities in the northern hemisphere is used to predict the latitudes of the cities given their humidity.
# * There is a weak positive relationship between humidity and latitude. That is, an increase in the humidity causes a slight increase in the latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Retrieve the cloudiness and Latitude for northern hemisphere
North_city_data.head()
North_cloud = North_city_data.iloc[:,8]
North_lat = North_city_data.iloc[:,6]

# Perform linear regression of cloudiness vs. Latitude
NCL_slope, NCL_int, NCL_r, NCL_p, NCL_std_err = linregress(North_cloud, North_lat)
NCL_fit = NCL_slope * North_cloud + NCL_int
print(NCL_fit)

# Print the regression equation
NorthCL_equation =  f"y={round(NCL_slope, 2)}x + {round(NCL_int,2)}"
print(NorthCL_equation)

# Compute and print the correlation 
print(f" Correlation = {round((NCL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(North_cloud, NCL_fit, color="red")
plt.annotate(NorthCL_equation,(20,70), fontsize=12, color ="red")
plt.scatter(North_cloud, North_lat)
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere City Cloudiness vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure9.png")
plt.show()
# Out:
# 0      40.177456
# 1      41.635180
# 2      41.171359
# 3      41.833961
# 4      35.207943
#          ...
# 574    38.388432
# 575    40.177456
# 577    41.833961
# 578    35.472984
# 579    41.833961
# Name: Cloudiness, Length: 382, dtype: float64
# y=0.07x + 35.21
#  Correlation = 0.13

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between cloudiness and latitude of cities in the northern hemisphere is used to predict the latitudes of the cities given their cloudiness.
# * There is a weak positive relationship between cloudiness and latitude. That is, an increase in the cloudiness causes a slight increase in the latitude.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Retrieve the cloudiness and Latitude for northern hemisphere
South_city_data.head()
South_cloud = South_city_data.iloc[:,8]
South_lat = South_city_data.iloc[:,6]

# Perform linear regression of cloudiness vs. Latitude
SCL_slope, SCL_int, SCL_r, SCL_p, SCL_std_err = linregress(South_cloud, South_lat)
SCL_fit = SCL_slope * South_cloud + SCL_int
print(SCL_fit)

# Print the regression equation
SouthCL_equation =  f"y={round(SCL_slope, 2)}x + ({round(SCL_int,2)})"
print(SouthCL_equation)

# Compute and print the correlation
print(f" Correlation = {round((SCL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.annotate(SouthCL_equation,(10,-50), fontsize=12, color ="red")
plt.plot(South_cloud, SCL_fit, color="red")
plt.scatter(South_cloud, South_lat)
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere City Cloudiness vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure10.png")
plt.show()
# Out:
# 6     -24.006739
# 7     -26.195734
# 8     -17.987000
# 9     -20.394896
# 13    -16.345253
#          ...
# 555   -25.648486
# 558   -23.459490
# 568   -22.583891
# 571   -17.987000
# 576   -26.195734
# Name: Cloudiness, Length: 198, dtype: float64
# y=0.11x + (-26.2)
#  Correlation = 0.31

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between cloudiness and latitude of cities in the southern hemisphere is used to predict the latitudes of the cities given their cloudiness.
# * There is a weak positive relationship between cloudiness and latitude. That is, an increase in the cloudiness causes a slight increase in the latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Retrieve the wind speed and Latitude for northern hemisphere
North_city_data.head()
North_windspeed = North_city_data.iloc[:,7]
North_lat = North_city_data.iloc[:,6]

# Perform linear regression of wind speed vs. Latitude
NWL_slope, NWL_int, NWL_r, NWL_p, NWL_std_err = linregress(North_windspeed, North_lat)
NWL_fit = NWL_slope * North_windspeed + NWL_int
print(NWL_fit)

# Print the regression equation
NorthWL_equation =  f"y={round(NWL_slope, 2)}x + {round(NWL_int,2)}"
print(NorthWL_equation)

# Compute and print the correlation 
print(f" Correlation = {round((NWL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(North_windspeed, NWL_fit, color="red")
plt.annotate(NorthWL_equation,(10,10), fontsize=12, color ="red")
plt.scatter(North_windspeed, North_lat)
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere City Wind Speed vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure11.png")
plt.show()
# Out:
# 0      37.013583
# 1      43.007041
# 2      38.890449
# 3      48.762763
# 4      35.011593
#          ...
# 574    36.225300
# 575    35.261842
# 577    34.736319
# 578    35.061643
# 579    42.018559
# Name: WindSpeed, Length: 382, dtype: float64
# y=1.25x + 33.76
#  Correlation = 0.17

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between the wind speed and latitude of cities in the northern hemisphere is used to predict the latitudes of the cities given their wind speed.
# * There is a weak positive relationship between wind speed and latitude. That is, an increase in the wind speed causes a slight increase in the latitude.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Retrieve the wind speed and Latitude for southern hemisphere
South_city_data.head()
South_windspeed = South_city_data.iloc[:,7]
South_lat = South_city_data.iloc[:,6]

# Perform linear regression of wind speed vs. Latitude
SWL_slope, SWL_int, SWL_r, SWL_p, SWL_std_err = linregress(South_windspeed, South_lat)
SWL_fit = SWL_slope * South_windspeed + SWL_int
print(SWL_fit)

# Print the regression equation
SouthWL_equation =  f"y={round(SWL_slope, 2)}x + ({round(SWL_int,2)})"
print(SouthWL_equation)

# Compute and print the correlation 
print(f" Correlation = {round((SWL_r),2)}")

# Plot the graph of linear regression on the 
# scatter plots of MaxTemp vs. Latitude
# Include the axes labels, plot title, and date of analysis
plt.plot(South_windspeed, SWL_fit, color="red")
plt.annotate(SouthWL_equation,(2,-50), fontsize=12, color ="red")
plt.scatter(South_windspeed, South_lat)
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere City Wind Speed vs. Latitude (%s)" % time.strftime("%x"))

# Save the plotted graph as .png
plt.savefig("../output_data/Figure12.png")
plt.show()
# Out:
# 6     -20.773574
# 7     -24.690707
# 8     -26.322845
# 9     -26.279321
# 13    -22.405713
#          ...
# 555   -18.967341
# 558   -21.469954
# 568   -18.923818
# 571   -26.866891
# 576   -24.690707
# Name: WindSpeed, Length: 198, dtype: float64
# y=-1.09x + (-17.4)
#  Correlation = -0.21

# %% [markdown]
# #### What does the linear regression model?
# * The linear regression between the wind speed and latitude of cities in the southern hemisphere is used to predict the latitudes of the cities given their wind speed.
# * There is a weak negative relationship between wind speed and latitude. That is, an increase in the wind speed causes a slight decrease in the latitude.
